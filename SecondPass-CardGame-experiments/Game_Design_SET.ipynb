# %% [markdown]
# ### New Version of dataraw_full_matrix

# %%
# %load_ext autoreload
# %autoreload 2

from collections import defaultdict, Counter
import numpy as np
import itertools
import copy
import matplotlib.pyplot as plt
import random
from dataraw_sampling import gen_random_dataset, gen_full_dataset, gen_full_matrices, construct_full_matrix, report_countable_distribution
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set Rules Multiple card queries

# %%
# SET rules 4 3 2
count_table, xy, xyind, xy_div_xyind, distribution = gen_full_matrices(num_attributes=4, num_attr_vals=3, num_cards_per_query=2, nest_depth_int=2)

# %%
# SET rules 4 3 2
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,:800])

# %%
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 80
# [729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729.]

# %%
# SET rules 3 3 4
count_table, xy, xyind, xy_div_xyind, distribution = gen_full_matrices(num_attributes=3, num_attr_vals=3, num_cards_per_query=4, nest_depth_int=2)

# %%
# SET rules 3 3 4
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,:800])

# %%
# SET rules 3 3 4
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,-800:])

# %%
# SET rules 3 3 4 SVD cannot run
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)

# %%
# SET rules 2 3 4
count_table, xy, xyind, xy_div_xyind, distribution = gen_full_matrices(num_attributes=2, num_attr_vals=3, num_cards_per_query=4, nest_depth_int=2)

# %%
# SET rules 2 3 4
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,:800])

# %%
# SET rules 2 3 4
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 8
# [243. 243. 243. 243. 243. 243. 243. 243.]

# %%
# SET rules 2 3 4
print(np.linalg.matrix_rank(xy[:-1, :]))
u, s, vh = np.linalg.svd(xy[:-1, :])
print(s)
plt.plot(s)
# Out:
# 2
# [0.19245009 0.19245009]

# %%
# SET rules 2 3 3
count_table, xy, xyind, xy_div_xyind, distribution = gen_full_matrices(num_attributes=2, num_attr_vals=3, num_cards_per_query=3, nest_depth_int=2)

# %%
# SET rules 2 3 3
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,:800])

# %%
# SET rules 2 3 3
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 8
# [81. 81. 81. 81. 81. 81. 81. 81.]

# %%
# SET rules 2 3 2
count_table, xy, xyind, xy_div_xyind, distribution = gen_full_matrices(num_attributes=2, num_attr_vals=3, num_cards_per_query=2, nest_depth_int=2)

# %%
# SET rules 2 3 2
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,:800])

# %%
# SET rules 2 3 2
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 8
# [27. 27. 27. 27. 27. 27. 27. 27.]

# %%
# SET rules 1 3 2
count_table, xy, xyind, xy_div_xyind, distribution = gen_full_matrices(num_attributes=1, num_attr_vals=3, num_cards_per_query=2, nest_depth_int=2)

# %%
# SET rules 1 3 2
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,:800])

# %%
# SET rules 1 3 2
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 2
# [5.19615242 5.19615242]

# %% [markdown]
# ## Set Rules

# %%
# SET rules 5 3 2
count_table = construct_full_matrix(num_attributes=5, num_attr_vals=3, num_cards_per_query=2, nest_depth_int=1)
# Out:
# Constructed Full Matrix:
# 243 keys by 59049 queries
# Total size 14348907
# Sparsity 0.00411522633744856

# %%
# SET rules 5 3 2
plt.figure(figsize=(20,15))
plt.imshow(count_table[:,:1200])

# %%
# SET rules 5 3 2
plt.figure(figsize=(10,15))
plt.imshow(count_table[:,:300])

# %%
# set rules 5 3 2 failed to run SVD
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 243

# %%
# SET rules 4 3 2
count_table = construct_full_matrix(num_attributes=4, num_attr_vals=3, num_cards_per_query=2, nest_depth_int=1)
# Out:
# Constructed Full Matrix:
# 81 keys by 6561 queries
# Total size 531441
# Sparsity 0.012345679012345678

# %%
# SET rules 4 3 2
plt.figure(figsize=(10,15))
plt.imshow(count_table[:,:300])

# %%
# set rules 4 3 2
_, xy, xyind, xy_div_xyind, distribution = report_countable_distribution(count_table)
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 80
# [729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729. 729.
#  729. 729. 729. 729. 729. 729. 729. 729. 729. 729.]

# %%
# SET rules 2 3 2
count_table = construct_full_matrix(num_attributes=2, num_attr_vals=3, num_cards_per_query=2, nest_depth_int=1)
# Out:
# Constructed Full Matrix:
# 9 keys by 81 queries
# Total size 729
# Sparsity 0.1111111111111111

# %%
# SET rules 2 3 2
plt.figure(figsize=(10,15))
plt.imshow(count_table[:,:300])

# %%
# set rules 2 3 2
_, xy, xyind, xy_div_xyind, distribution = report_countable_distribution(count_table)
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 8
# [27. 27. 27. 27. 27. 27. 27. 27.]

# %% [markdown]
# ## Earlier Rules (Code not working anymore)

# %%
# rule 2
plt.figure(figsize=(10,15))
plt.imshow(count_table[:,:300])

# %%
# rule 2
plt.imshow(xy_div_xyind[:,:300])

# %%
# rule 2
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 81
# [732.09884671 423.6930999  423.6930999  423.6930999  423.6930999
#  423.6930999  423.6930999  423.6930999  423.6930999  244.61932528
#  244.61932528 244.61932528 244.61932528 244.61932528 244.61932528
#  244.61932528 244.61932528 244.61932528 244.61932528 244.61932528
#  244.61932528 244.61932528 244.61932528 244.61932528 244.61932528
#  244.61932528 244.61932528 244.61932528 244.61932528 244.61932528
#  244.61932528 244.61932528 244.61932528 141.2310333  141.2310333
#  141.2310333  141.2310333  141.2310333  141.2310333  141.2310333
#  141.2310333  141.2310333  141.2310333  141.2310333  141.2310333
#  141.2310333  141.2310333  141.2310333  141.2310333  141.2310333
#  141.2310333  141.2310333  141.2310333  141.2310333  141.2310333
#  141.2310333  141.2310333  141.2310333  141.2310333  141.2310333
#  141.2310333  141.2310333  141.2310333  141.2310333  141.2310333
#   81.53977509  81.53977509  81.53977509  81.53977509  81.53977509
# ...

# %%
# rule 1
import matplotlib.pyplot as plt
plt.figure(figsize=(10,15))
plt.imshow(count_table[:,:300])

# %%
# rule 1
print(np.linalg.matrix_rank(xy_div_xyind[:-1, :]))
u, s, vh = np.linalg.svd(xy_div_xyind[:-1, :])
print(s)
plt.plot(s)
# Out:
# 81
# [657.28169548 260.38613132 260.38613132 260.38613132 260.38613132
#  260.38613132 260.38613132 260.38613132 260.38613132  37.19114702
#   37.19114702  37.19114702  37.19114702  37.19114702  37.19114702
#   37.19114702  37.19114702  37.19114702  37.19114702  37.19114702
#   37.19114702  37.19114702  37.19114702  37.19114702  37.19114702
#   37.19114702  37.19114702  37.19114702  37.19114702  37.19114702
#   37.19114702  37.19114702  37.19114702   6.56619619   6.56619619
#    6.56619619   6.56619619   6.56619619   6.56619619   6.56619619
#    6.56619619   6.56619619   6.56619619   6.56619619   6.56619619
#    6.56619619   6.56619619   6.56619619   6.56619619   6.56619619
#    6.56619619   6.56619619   6.56619619   6.56619619   6.56619619
#    6.56619619   6.56619619   6.56619619   6.56619619   6.56619619
#    6.56619619   6.56619619   6.56619619   6.56619619   6.56619619
#    1.25424247   1.25424247   1.25424247   1.25424247   1.25424247
# ...

# %%
# Rules

# multiple query parts
# simple key

# set


# existence
# count
# optimize

# %%
# First, hold the num attr and attr val the same -- same number of key cards
# Try to make the game more difficult like this.

# Hold num query cards at 2 for now.
# Does using AND rules increase the rank? -- should be harder?
# Does using set rules increase the rank? -- should be even harder?
