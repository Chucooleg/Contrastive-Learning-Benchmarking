# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_kl_loss():
    plt.figure(figsize=(15,15))
    # vec 4
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.193,0.301,0.467,0.6054],
            linestyle='dashed', marker='o')
    # vec 8
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.0009,0.201,0.337,0.4623],
            linestyle='dashed', marker='o')
    # vec 16
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.0009,0.071,0.127,0.1383],
            linestyle='dashed', marker='o')
    # vec 20
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.0007,0.03,0.056,0.05524],
            linestyle='dashed', marker='o')
    # vec 24
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.0007,0.0006,0.01269,0.005997],
            linestyle='dashed', marker='o')
    # vec 27
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.0008,0.0005,0.003146,0.002249],
            linestyle='dashed', marker='o')
   
    # vec 512
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.0007,0.0004,0.0003,0.002492],
            linestyle='dashed', marker='o')
    # vec Gen
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [0.00001,0.0007,0.0001,0.0002,0.00013],
            linestyle='dashed', marker='o')
    
    plt.xticks(ticks=[4, 6, 21, 22, 27], labels=['4','6','21','22','27'])
    plt.legend(["vec dim 4", "vec dim 8", "vec dim 16", "vec dim 20", "vec dim 24", "vec dim 27", "vec dim 512", "generative"])

    plt.show()

# %%
plot_kl_loss()

# %%
sudo scp -r -p -i ~/.ssh/id_rsa legg@20.187.45.108:/home/legg/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/wandb/run-20210401_210801-1c0kdzt3/  ~/
# Out:
#   File "<ipython-input-71-d6ead18a7a71>", line 1
#     sudo scp -r -p -i ~/.ssh/id_rsa legg@20.187.45.108:/home/legg/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/wandb/run-20210401_210801-1c0kdzt3/  ~/
#          ^
# SyntaxError: invalid syntax

# %%
def plot_topK_overall_ratio():
    plt.figure(figsize=(15,15))
    # vec 4
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1, 0.961, 0.84, 0.731, 0.65],
            linestyle='dashed', marker='o')
    # vec 8
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1,1,0.914, 0.825, 0.733],
            linestyle='dashed', marker='o')
    # vec 16
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1,1,0.97, 0.936, 0.917],
            linestyle='dashed', marker='o')
    # vec 20
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1,1,0.994, 0.979, 0.988],
            linestyle='dashed', marker='o')
    # vec 24
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1,1,1,0.997, 0.995],
            linestyle='dashed', marker='o')
    # vec 27
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1,1,1,0.998,1],
            linestyle='dashed', marker='o')
   
    # vec 512
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1,1,1,0.999,1],
            linestyle='dashed', marker='o')
    # vec Gen
    plt.plot([4.754887502163469, 6, 21.40003458928302, 22.660902499025667, 27], [1,1,1,1,1],
            linestyle='dashed', marker='o')
    
    plt.xticks(ticks=[4, 6, 21, 22, 27], labels=['4','6','21','22','27'])
    plt.legend(["vec 4", "vec 8", "vec 16", "vec 20", "vec 24", "vec 27", "vec 512", "Gen"])
    plt.show()

# %%
plot_topK_overall_ratio()

# %%
sudo -r -p -i legg@52.175.200.25:/home/legg/ContrastiveLearning-SET-Wildcard-Expand-SetOp-27/ ~/

# %%
def plot_81cards_KL_loss():
    plt.figure(figsize=(15,7.5))
    # KL Div Loss
    plt.plot([4, np.log2(24), 5, 6, np.log2(81), 7, 9], [0.5826, 0.284, 0.187, 0.017, 0.003, 0.001, 0.001],
            linestyle='-.', marker='o', color = 'm')
 
    # Non-Contrastive: KL-div
    plt.axhline(y=0.003, color='c', linestyle='dashed')
    
    plt.ylim(-0.1, 0.7)
    
    plt.xticks(ticks=[4, np.log2(24), 5, 6, np.log2(81), 7, 9], labels=['16','24','32','64','81', '128', '512'])
#     plt.legend(["KL Div Loss", "Top K Prediction-Groundtruth Overlap"])
    plt.show()

# %%
plot_81cards_KL_loss()

# %%
def plot_81cards_TopK():
    plt.figure(figsize=(15,7.5))
    
    # Top K Overlap
    plt.plot([4, np.log2(24), 5, 6, np.log2(81),7, 9], [0.741, 0.905, 0.957, 1, 1, 1, 1],
            linestyle='-.', marker='o', color='m')
    
    # Non-Contrastive: Top K
    plt.axhline(y=1.0, color='c', linestyle='dashed')
    
    plt.ylim(0.7, 1.05)
    
    plt.xticks(ticks=[4, np.log2(24), 5, 6, np.log2(81), 7, 9], labels=['16','24','32','64','81', '128', '512'])
#     plt.legend(["KL Div Loss", "Top K Prediction-Groundtruth Overlap"])
    plt.show()

# %%
plot_81cards_TopK()
