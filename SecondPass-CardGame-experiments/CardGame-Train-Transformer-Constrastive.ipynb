# %%
# https://discuss.pytorch.org/t/i-have-3-gpu-why-torch-cuda-device-count-only-return-1/7245/4
import torch
import sys
print('__Python VERSION:', sys.version)
print('__pyTorch VERSION:', torch.__version__)
print('__CUDA VERSION')
from subprocess import call
# call(["nvcc", "--version"]) does not work
! nvcc --version
print('__CUDNN VERSION:', torch.backends.cudnn.version())
print('__Number CUDA Devices:', torch.cuda.device_count())
print('__Devices')
call(["nvidia-smi", "--format=csv", "--query-gpu=index,name,driver_version,memory.total,memory.used,memory.free"])
print('Active CUDA Device: GPU', torch.cuda.current_device())

print ('Available devices ', torch.cuda.device_count())
print ('Current cuda device ', torch.cuda.current_device())
# Out:
# __Python VERSION: 3.8.3 (default, May 19 2020, 18:47:26)
# [GCC 7.3.0]
# __pyTorch VERSION: 1.7.0
# __CUDA VERSION
# /usr/bin/sh: 1: nvcc: not found
# __CUDNN VERSION: 8003
# __Number CUDA Devices: 2
# __Devices
# Active CUDA Device: GPU 0
# Available devices  2
# Current cuda device  0

# %%
# %load_ext autoreload
# %autoreload 2

import os
import json
import main
from argparse import ArgumentDefaultsHelpFormatter, ArgumentParser
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/user/.netrc

# %%
# arguments
parser = ArgumentParser(formatter_class=ArgumentDefaultsHelpFormatter)
args = parser.parse_args('')

args.data_path = '../Raw_Datasets/3Attr-4Vals-2hat23Train-2hat12Val.json'
args.config_path = 'config.json'
args.generate_full_matrix = True
args.checkpoint_dir = 'checkpoints'
args.mode = 'train'
args.gpu = 0
args.approve_before_training = True

# %%
main.main(args)
# Out:
# ---------data----------
# num_attributes : 3
# num_attr_vals : 4
# key_support_size : 65
# query_support_size : 4096
# train_datapoints length : 8388608
# val_datapoints length : 4096
# sparsity_estimate : 0.17980795755722673
# -----------------------
# ----------hparams----------
# seed : 42
# batch_size : 128
# max_epochs : 1
# d_model : 65
# embed_dropout : 0.0
# model : contrastive
# embedding_by_property : True
# encoder : transformer
# decoder : transformer
# d_ff : 1024
# num_heads : 1
# N_enc : 2
# N_dec : 2
# attn_wt_tying_scheme : untie_QKVO_zero_O
# attn_wt_dropout : 0.0
# heads_dropout : 0.0
# pff_dropout : 0.0
# representation_pos : 0
# dotproduct_bottleneck : True
# loss_temperature_const : 1.0
# loss_smoothing_const : 0.1
# nonlinear_classifier_scale_down_factor : [2, 1]
# adam_lr : 0.001
# adam_beta1 : 0.9
# adam_beta2 : 0.999
# adam_epsilon : 1e-08
# adam_weight_decay : 0
# scheduled_adam_beta1 : 0.9
# scheduled_adam_beta2 : 0.98
# scheduled_adam_epsilon : 1e-09
# scheduled_adam_warmup_steps : 4000
# gradient_clip_val : 0
# debug : False
# key_support_size : 65
# query_support_size : 4096
# num_attributes : 3
# num_attr_vals : 4
# num_cards_per_query : 2
# vocab_size : 17
# NULL : 12
# SEP : 13
# SOS : 14
# EOS : 15
# PAD : 16
# populate_logits_matrix : True
# len_q : 8
# len_k : 4
# ---------------------------
# Continue to build model? (y/n)y
# Generating Full Matrix
# Generated 65 unqiue cards
# Generated 4096 cardpairs
# -- 2368 cardpairs with shared concept
# -- 1728 cardpairs without shared concept
# Number of cardpairs per shared concept [(1, 1728), (0, 1728), (2, 576), (3, 64)]
# Total number of matches =  47872
# Number of matches per key concept hit =  [(1, 43200), (2, 2880), (0, 1728), (3, 64)]
# Global seed set to 42
# {'shape': (65, 4096), 'size': 266240, 'sparsity': 0.1798076923076923, 'xy_rank': 65, 'xy_div_xyind_rank': 65}
#    | Name                                                              | Type                   | Params
# --------------------------------------------------------------------------------------------------------------
# 0  | metrics                                                           | ThresholdedMetrics     | 0
# 1  | model                                                             | EncoderPredictor       | 608 K
# 2  | model.inp_query_layer                                             | Sequential             | 1.6 K
# 3  | model.inp_query_layer.scaled_embed                                | ScaledEmbedding        | 1.1 K
# 4  | model.inp_query_layer.scaled_embed.embedding                      | Embedding              | 1.1 K
# 5  | model.inp_query_layer.position_encoder                            | LearnedPositionEncoder | 520
# 6  | model.inp_query_layer.embed_dropout                               | Dropout                | 0
# 7  | model.inp_key_layer                                               | Sequential             | 1.6 K
# 8  | model.query_encoder                                               | Encoder                | 303 K
# 9  | model.query_encoder.encoder_layers                                | ModuleList             | 303 K
# 10 | model.query_encoder.encoder_layers.0                              | EncoderLayer           | 151 K
# 11 | model.query_encoder.encoder_layers.0.poswise_ff                   | Positiontwise_FF       | 134 K
# 12 | model.query_encoder.encoder_layers.0.poswise_ff.linear1           | Linear                 | 67.6 K
# 13 | model.query_encoder.encoder_layers.0.poswise_ff.linear2           | Linear                 | 66.6 K
# 14 | model.query_encoder.encoder_layers.0.self_attn                    | MultiHeadAttention     | 17.2 K
# 15 | model.query_encoder.encoder_layers.0.self_attn.attn_wt_dropout    | Dropout                | 0
# 16 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO   | ModuleList             | 17.2 K
# 17 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.0 | Linear                 | 4.3 K
# 18 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.1 | Linear                 | 4.3 K
# 19 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.2 | Linear                 | 4.3 K
# 20 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.3 | Linear                 | 4.3 K
# 21 | model.query_encoder.encoder_layers.0.layer_norms                  | ModuleList             | 260
# 22 | model.query_encoder.encoder_layers.0.layer_norms.0                | LayerNorm              | 130
# 23 | model.query_encoder.encoder_layers.0.layer_norms.1                | LayerNorm              | 130
# 24 | model.query_encoder.encoder_layers.0.heads_dropout                | Dropout                | 0
# 25 | model.query_encoder.encoder_layers.0.pff_dropout                  | Dropout                | 0
# 26 | model.query_encoder.encoder_layers.1                              | EncoderLayer           | 151 K
# 27 | model.query_encoder.encoder_layers.1.poswise_ff                   | Positiontwise_FF       | 134 K
# 28 | model.query_encoder.encoder_layers.1.poswise_ff.linear1           | Linear                 | 67.6 K
# 29 | model.query_encoder.encoder_layers.1.poswise_ff.linear2           | Linear                 | 66.6 K
# 30 | model.query_encoder.encoder_layers.1.self_attn                    | MultiHeadAttention     | 17.2 K
# 31 | model.query_encoder.encoder_layers.1.self_attn.attn_wt_dropout    | Dropout                | 0
# 32 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO   | ModuleList             | 17.2 K
# 33 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.0 | Linear                 | 4.3 K
# 34 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.1 | Linear                 | 4.3 K
# 35 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.2 | Linear                 | 4.3 K
# 36 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.3 | Linear                 | 4.3 K
# 37 | model.query_encoder.encoder_layers.1.layer_norms                  | ModuleList             | 260
# 38 | model.query_encoder.encoder_layers.1.layer_norms.0                | LayerNorm              | 130
# 39 | model.query_encoder.encoder_layers.1.layer_norms.1                | LayerNorm              | 130
# 40 | model.query_encoder.encoder_layers.1.heads_dropout                | Dropout                | 0
# 41 | model.query_encoder.encoder_layers.1.pff_dropout                  | Dropout                | 0
# 42 | model.key_encoder                                                 | Encoder                | 303 K
# 43 | model.key_encoder.encoder_layers                                  | ModuleList             | 303 K
# 44 | model.key_encoder.encoder_layers.0                                | EncoderLayer           | 151 K
# 45 | model.key_encoder.encoder_layers.0.poswise_ff                     | Positiontwise_FF       | 134 K
# 46 | model.key_encoder.encoder_layers.0.poswise_ff.linear1             | Linear                 | 67.6 K
# 47 | model.key_encoder.encoder_layers.0.poswise_ff.linear2             | Linear                 | 66.6 K
# 48 | model.key_encoder.encoder_layers.0.self_attn                      | MultiHeadAttention     | 17.2 K
# 49 | model.key_encoder.encoder_layers.0.self_attn.attn_wt_dropout      | Dropout                | 0
# 50 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO     | ModuleList             | 17.2 K
# 51 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.0   | Linear                 | 4.3 K
# 52 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.1   | Linear                 | 4.3 K
# 53 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.2   | Linear                 | 4.3 K
# 54 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.3   | Linear                 | 4.3 K
# 55 | model.key_encoder.encoder_layers.0.layer_norms                    | ModuleList             | 260
# 56 | model.key_encoder.encoder_layers.0.layer_norms.0                  | LayerNorm              | 130
# 57 | model.key_encoder.encoder_layers.0.layer_norms.1                  | LayerNorm              | 130
# 58 | model.key_encoder.encoder_layers.0.heads_dropout                  | Dropout                | 0
# 59 | model.key_encoder.encoder_layers.0.pff_dropout                    | Dropout                | 0
# 60 | model.key_encoder.encoder_layers.1                                | EncoderLayer           | 151 K
# 61 | model.key_encoder.encoder_layers.1.poswise_ff                     | Positiontwise_FF       | 134 K
# 62 | model.key_encoder.encoder_layers.1.poswise_ff.linear1             | Linear                 | 67.6 K
# 63 | model.key_encoder.encoder_layers.1.poswise_ff.linear2             | Linear                 | 66.6 K
# 64 | model.key_encoder.encoder_layers.1.self_attn                      | MultiHeadAttention     | 17.2 K
# 65 | model.key_encoder.encoder_layers.1.self_attn.attn_wt_dropout      | Dropout                | 0
# 66 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO     | ModuleList             | 17.2 K
# 67 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.0   | Linear                 | 4.3 K
# 68 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.1   | Linear                 | 4.3 K
# 69 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.2   | Linear                 | 4.3 K
# 70 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.3   | Linear                 | 4.3 K
# 71 | model.key_encoder.encoder_layers.1.layer_norms                    | ModuleList             | 260
# 72 | model.key_encoder.encoder_layers.1.layer_norms.0                  | LayerNorm              | 130
# 73 | model.key_encoder.encoder_layers.1.layer_norms.1                  | LayerNorm              | 130
# 74 | model.key_encoder.encoder_layers.1.heads_dropout                  | Dropout                | 0
# 75 | model.key_encoder.encoder_layers.1.pff_dropout                    | Dropout                | 0
# 76 | loss_criterion                                                    | InfoCELoss             | 0
# 77 | loss_criterion.CE_loss                                            | CrossEntropyLoss       | 0
# 78 | softmax                                                           | Softmax                | 0
# --------------------------------------------------------------------------------------------------------------
# 608 K     Trainable params
# 0         Non-trainable params
# 608 K     Total params
#
# RUN NAME :
#  CardGame:OR;attr3-val4;contrastive;embedByProperty;d_model65;dot-product;params608.14K
# Continue training? (y/n)y
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: Checkpoint directory checkpoints/ContrastiveLearning-cardgame-Scaling-SecondPass/20210223-043618-CardGame:OR;attr3-val4;contrastive;embedByProperty;d_model65;dot-product;params608.14K exists and is not empty.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: False
# TPU available: None, using: 0 TPU cores
# Checkpoint Path:
#  checkpoints/ContrastiveLearning-cardgame-Scaling-SecondPass/20210223-043618-CardGame:OR;attr3-val4;contrastive;embedByProperty;d_model65;dot-product;params608.14K
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: GPU available but not used. Set the --gpus flag when calling the script.
#   warnings.warn(*args, **kwargs)
# /app/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/main.py:213: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   with torch.autograd.detect_anomaly():
# wandb: wandb version 0.10.20 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.18<br/>
#                 Syncing run <strong style="color:#cdcd00">CardGame:OR;attr3-val4;contrastive;embedByProperty;d_model65;dot-product;params608.14K</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Scaling-SecondPass" target="_blank">https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Scaling-SecondPass</a><br/>
#                 Run page: <a href="https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Scaling-SecondPass/runs/21paflco" target="_blank">https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Scaling-SecondPass/runs/21paflco</a><br/>
#                 Run data is saved locally in <code>/app/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/wandb/run-20210223_043618-21paflco</code><br/><br/>
# wandb: WARNING Serializing object of type ndarray that is 2130032 bytes
# wandb: WARNING Serializing object of type ndarray that is 2130032 bytes
# wandb: WARNING Serializing object of type ndarray that is 2130032 bytes
# wandb: WARNING Serializing object of type ndarray that is 2130032 bytes
#
#    | Name                                                              | Type                   | Params
# --------------------------------------------------------------------------------------------------------------
# 0  | metrics                                                           | ThresholdedMetrics     | 0
# 1  | model                                                             | EncoderPredictor       | 608 K
# 2  | model.inp_query_layer                                             | Sequential             | 1.6 K
# 3  | model.inp_query_layer.scaled_embed                                | ScaledEmbedding        | 1.1 K
# 4  | model.inp_query_layer.scaled_embed.embedding                      | Embedding              | 1.1 K
# 5  | model.inp_query_layer.position_encoder                            | LearnedPositionEncoder | 520
# 6  | model.inp_query_layer.embed_dropout                               | Dropout                | 0
# 7  | model.inp_key_layer                                               | Sequential             | 1.6 K
# 8  | model.query_encoder                                               | Encoder                | 303 K
# 9  | model.query_encoder.encoder_layers                                | ModuleList             | 303 K
# 10 | model.query_encoder.encoder_layers.0                              | EncoderLayer           | 151 K
# 11 | model.query_encoder.encoder_layers.0.poswise_ff                   | Positiontwise_FF       | 134 K
# 12 | model.query_encoder.encoder_layers.0.poswise_ff.linear1           | Linear                 | 67.6 K
# 13 | model.query_encoder.encoder_layers.0.poswise_ff.linear2           | Linear                 | 66.6 K
# 14 | model.query_encoder.encoder_layers.0.self_attn                    | MultiHeadAttention     | 17.2 K
# 15 | model.query_encoder.encoder_layers.0.self_attn.attn_wt_dropout    | Dropout                | 0
# 16 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO   | ModuleList             | 17.2 K
# 17 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.0 | Linear                 | 4.3 K
# 18 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.1 | Linear                 | 4.3 K
# 19 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.2 | Linear                 | 4.3 K
# 20 | model.query_encoder.encoder_layers.0.self_attn.projections_QKVO.3 | Linear                 | 4.3 K
# 21 | model.query_encoder.encoder_layers.0.layer_norms                  | ModuleList             | 260
# 22 | model.query_encoder.encoder_layers.0.layer_norms.0                | LayerNorm              | 130
# 23 | model.query_encoder.encoder_layers.0.layer_norms.1                | LayerNorm              | 130
# 24 | model.query_encoder.encoder_layers.0.heads_dropout                | Dropout                | 0
# 25 | model.query_encoder.encoder_layers.0.pff_dropout                  | Dropout                | 0
# 26 | model.query_encoder.encoder_layers.1                              | EncoderLayer           | 151 K
# 27 | model.query_encoder.encoder_layers.1.poswise_ff                   | Positiontwise_FF       | 134 K
# 28 | model.query_encoder.encoder_layers.1.poswise_ff.linear1           | Linear                 | 67.6 K
# 29 | model.query_encoder.encoder_layers.1.poswise_ff.linear2           | Linear                 | 66.6 K
# 30 | model.query_encoder.encoder_layers.1.self_attn                    | MultiHeadAttention     | 17.2 K
# 31 | model.query_encoder.encoder_layers.1.self_attn.attn_wt_dropout    | Dropout                | 0
# 32 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO   | ModuleList             | 17.2 K
# 33 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.0 | Linear                 | 4.3 K
# 34 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.1 | Linear                 | 4.3 K
# 35 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.2 | Linear                 | 4.3 K
# 36 | model.query_encoder.encoder_layers.1.self_attn.projections_QKVO.3 | Linear                 | 4.3 K
# 37 | model.query_encoder.encoder_layers.1.layer_norms                  | ModuleList             | 260
# 38 | model.query_encoder.encoder_layers.1.layer_norms.0                | LayerNorm              | 130
# 39 | model.query_encoder.encoder_layers.1.layer_norms.1                | LayerNorm              | 130
# 40 | model.query_encoder.encoder_layers.1.heads_dropout                | Dropout                | 0
# 41 | model.query_encoder.encoder_layers.1.pff_dropout                  | Dropout                | 0
# 42 | model.key_encoder                                                 | Encoder                | 303 K
# 43 | model.key_encoder.encoder_layers                                  | ModuleList             | 303 K
# 44 | model.key_encoder.encoder_layers.0                                | EncoderLayer           | 151 K
# 45 | model.key_encoder.encoder_layers.0.poswise_ff                     | Positiontwise_FF       | 134 K
# 46 | model.key_encoder.encoder_layers.0.poswise_ff.linear1             | Linear                 | 67.6 K
# 47 | model.key_encoder.encoder_layers.0.poswise_ff.linear2             | Linear                 | 66.6 K
# 48 | model.key_encoder.encoder_layers.0.self_attn                      | MultiHeadAttention     | 17.2 K
# 49 | model.key_encoder.encoder_layers.0.self_attn.attn_wt_dropout      | Dropout                | 0
# 50 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO     | ModuleList             | 17.2 K
# 51 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.0   | Linear                 | 4.3 K
# 52 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.1   | Linear                 | 4.3 K
# 53 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.2   | Linear                 | 4.3 K
# 54 | model.key_encoder.encoder_layers.0.self_attn.projections_QKVO.3   | Linear                 | 4.3 K
# 55 | model.key_encoder.encoder_layers.0.layer_norms                    | ModuleList             | 260
# 56 | model.key_encoder.encoder_layers.0.layer_norms.0                  | LayerNorm              | 130
# 57 | model.key_encoder.encoder_layers.0.layer_norms.1                  | LayerNorm              | 130
# 58 | model.key_encoder.encoder_layers.0.heads_dropout                  | Dropout                | 0
# 59 | model.key_encoder.encoder_layers.0.pff_dropout                    | Dropout                | 0
# 60 | model.key_encoder.encoder_layers.1                                | EncoderLayer           | 151 K
# 61 | model.key_encoder.encoder_layers.1.poswise_ff                     | Positiontwise_FF       | 134 K
# 62 | model.key_encoder.encoder_layers.1.poswise_ff.linear1             | Linear                 | 67.6 K
# 63 | model.key_encoder.encoder_layers.1.poswise_ff.linear2             | Linear                 | 66.6 K
# 64 | model.key_encoder.encoder_layers.1.self_attn                      | MultiHeadAttention     | 17.2 K
# 65 | model.key_encoder.encoder_layers.1.self_attn.attn_wt_dropout      | Dropout                | 0
# 66 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO     | ModuleList             | 17.2 K
# 67 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.0   | Linear                 | 4.3 K
# 68 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.1   | Linear                 | 4.3 K
# 69 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.2   | Linear                 | 4.3 K
# 70 | model.key_encoder.encoder_layers.1.self_attn.projections_QKVO.3   | Linear                 | 4.3 K
# 71 | model.key_encoder.encoder_layers.1.layer_norms                    | ModuleList             | 260
# 72 | model.key_encoder.encoder_layers.1.layer_norms.0                  | LayerNorm              | 130
# 73 | model.key_encoder.encoder_layers.1.layer_norms.1                  | LayerNorm              | 130
# 74 | model.key_encoder.encoder_layers.1.heads_dropout                  | Dropout                | 0
# 75 | model.key_encoder.encoder_layers.1.pff_dropout                    | Dropout                | 0
# 76 | loss_criterion                                                    | InfoCELoss             | 0
# 77 | loss_criterion.CE_loss                                            | CrossEntropyLoss       | 0
# 78 | softmax                                                           | Softmax                | 0
# --------------------------------------------------------------------------------------------------------------
# 608 K     Trainable params
# 0         Non-trainable params
# 608 K     Total params
# Validation sanity check:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Epoch 0:   0%|          | 0/67616 [00:00<?, ?it/s]
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The validation_epoch_end should not return anything as of 9.1. To log, use self.log(...) or self.write(...) directly in the LightningModule
#   warnings.warn(*args, **kwargs)
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Epoch 0:   1%|▏         | 1000/67616 [13:42<15:13:32,  1.22it/s, loss=529, v_num=flco]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 0:   1%|▏         | 1002/67616 [13:43<15:12:03,  1.22it/s, loss=529, v_num=flco]
# Validating:   6%|▋         | 2/32 [00:00<00:09,  3.20it/s]
# Epoch 0:   1%|▏         | 1004/67616 [13:43<15:10:59,  1.22it/s, loss=529, v_num=flco]
# Validating:  12%|█▎        | 4/32 [00:01<00:09,  3.03it/s]
# Epoch 0:   1%|▏         | 1006/67616 [13:44<15:09:51,  1.22it/s, loss=529, v_num=flco]
# Validating:  19%|█▉        | 6/32 [00:02<00:09,  2.87it/s]
# Epoch 0:   1%|▏         | 1008/67616 [13:45<15:08:51,  1.22it/s, loss=529, v_num=flco]
# Validating:  25%|██▌       | 8/32 [00:02<00:08,  2.90it/s]
# Epoch 0:   1%|▏         | 1010/67616 [13:45<15:07:44,  1.22it/s, loss=529, v_num=flco]
# Validating:  31%|███▏      | 10/32 [00:03<00:07,  3.02it/s]
# Epoch 0:   1%|▏         | 1012/67616 [13:46<15:06:36,  1.22it/s, loss=529, v_num=flco]
# Validating:  38%|███▊      | 12/32 [00:04<00:06,  2.93it/s]
# Epoch 0:   1%|▏         | 1014/67616 [13:47<15:05:33,  1.23it/s, loss=529, v_num=flco]
# Validating:  44%|████▍     | 14/32 [00:04<00:05,  3.07it/s]
# Epoch 0:   2%|▏         | 1016/67616 [13:47<15:04:25,  1.23it/s, loss=529, v_num=flco]
# Validating:  50%|█████     | 16/32 [00:05<00:05,  3.07it/s]
# Epoch 0:   2%|▏         | 1018/67616 [13:48<15:03:20,  1.23it/s, loss=529, v_num=flco]
# Validating:  56%|█████▋    | 18/32 [00:05<00:04,  3.13it/s]
# Epoch 0:   2%|▏         | 1020/67616 [13:49<15:02:11,  1.23it/s, loss=529, v_num=flco]
# Validating:  62%|██████▎   | 20/32 [00:06<00:03,  3.19it/s]
# Epoch 0:   2%|▏         | 1022/67616 [13:49<15:01:06,  1.23it/s, loss=529, v_num=flco]
# Validating:  69%|██████▉   | 22/32 [00:07<00:03,  3.05it/s]
# Epoch 0:   2%|▏         | 1024/67616 [13:50<15:00:04,  1.23it/s, loss=529, v_num=flco]
# Validating:  75%|███████▌  | 24/32 [00:07<00:02,  3.05it/s]
# Epoch 0:   2%|▏         | 1026/67616 [13:51<14:59:00,  1.23it/s, loss=529, v_num=flco]
# Validating:  81%|████████▏ | 26/32 [00
v_num=flco]
# Validating:  81%|████████▏ | 26/32 [00:08<00:01,  3.10it/s]
# Epoch 0:   8%|▊         | 5160/67616 [1:07:28<13:36:37,  1.27it/s, loss=487, v_num=flco]
# Validating:  88%|████████▊ | 28/32 [00:09<00:01,  3.25it/s]
# Epoch 0:   8%|▊         | 5162/67616 [1:07:28<13:36:24,  1.27it/s, loss=487, v_num=flco]
# Validating:  94%|█████████▍| 30/32 [00:10<00:00,  2.78it/s]
# Epoch 0:   8%|▊         | 5164/67616 [1:07:29<13:36:14,  1.28it/s, loss=487, v_num=flco]
# Epoch 0:   8%|▊         | 5165/67616 [1:07:30<13:36:11,  1.28it/s, loss=487, v_num=flco]
# Epoch 0:   9%|▉         | 6166/67616 [1:20:34<13:23:04,  1.28it/s, loss=483, v_num=flco]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/32 [00:00<?, ?it/s]
# Validating:   3%|▎         | 1/32 [00:00<00:09,  3.25it/s]
# Epoch 0:   9%|▉         | 6168/67616 [1:20:35<13:22:53,  1.28it/s, loss=483, v_num=flco]
# Validating:   9%|▉         | 3/32 [00:00<00:08,  3.29it/s]
# Epoch 0:   9%|▉         | 6170/67616 [1:20:36<13:22:42,  1.28it/s, loss=483, v_num=flco]
# Validating:  16%|█▌        | 5/32 [00:01<00:08,  3.37it/s]
# Epoch 0:   9%|▉         | 6172/67616 [1:20:36<13:22:30,  1.28it/s, loss=483, v_num=flco]
# Validating:  22%|██▏       | 7/32 [00:02<00:07,  3.35it/s]
# Epoch 0:   9%|▉         | 6174/67616 [1:20:37<13:22:19,  1.28it/s, loss=483, v_num=flco]
# Validating:  28%|██▊       | 9/32 [00:02<00:06,  3.33it/s]
# Epoch 0:   9%|▉         | 6176/67616 [1:20:37<13:22:09,  1.28it/s, loss=483, v_num=flco]
# Validating:  34%|███▍      | 11/32 [00:03<00:06,  3.07it/s]
# Epoch 0:   9%|▉         | 6178/67616 [1:20:38<13:21:58,  1.28it/s, loss=483, v_num=flco]
# Validating:  41%|████      | 13/32 [00:04<00:06,  2.92it/s]
# Epoch 0:   9%|▉         | 6180/67616 [1:20:39<13:21:47,  1.28it/s, loss=483, v_num=flco]
# Validating:  47%|████▋     | 15/32 [00:04<00:05,  3.07it/s]
# Epoch 0:   9%|▉         | 6182/67616 [1:20:40<13:21:37,  1.28it/s, loss=483, v_num=flco]
# Validating:  53%|█████▎    | 17/32 [00:05<00:05,  2.93it/s]
# Epoch 0:   9%|▉         | 6184/67616 [1:20:40<13:21:27,  1.28it/s, loss=483, v_num=flco]
# Validating:  59%|█████▉    | 19/32 [00:06<00:04,  3.05it/s]
# Epoch 0:   9%|▉         | 6186/67616 [1:20:41<13:21:16,  1.28it/s, loss=483, v_num=flco]
# Validating:  66%|██████▌   | 21/32 [00:06<00:03,  2.95it/s]
# Epoch 0:   9%|▉         | 6188/67616 [1:20:42<13:21:06,  1.28it/s, loss=483, v_num=flco]
# Validating:  72%|███████▏  | 23/32 [00:07<00:02,  3.00it/s]
# Epoch 0:   9%|▉         | 6190/67616 [1:20:42<13:20:56,  1.28it/s, loss=483, v_num=flco]
# Validating:  78%|███████▊  | 25/32 [00:08<00:02,  2.75it/s]
# Epoch 0:   9%|▉         | 6192/67616 [1:20:43<13:20:46,  1.28it/s, loss=483, v_num=flco]
# Validating:  84%|████████▍ | 27/32 [00:08<00:01,  2.90it/s]
# Epoch 0:   9%|▉         | 6194/67616 [1:20:44<13:20:36,  1.28it/s, loss=483, v_num=flco]
# Validating:  91%|█████████ | 29/32 [00:09<00:00,  3.01it/s]
# Epoch 0:   9%|▉         | 6196/67616 [1:20:44<13:20:25,  1.28it/s, loss=483, v_num=flco]
# Validating:  97%|█████████▋| 31/32 [00:10<00:00,  3.16it/s]
# Epoch 0:   9%|▉         | 6198/67616 [1:20:45<13:20:15,  1.28it/s, loss=483, v_num=flco]
# Epoch 0:  11%|█         | 7198/67616 [1:34:00<13:09:03,  1.28it/s, loss=482, v_num=flco]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 0
# Epoch 0:  95%|█████████▍| 64028/67616 [13:13:48<44:29,  1.34it/s, loss=480, v_num=flco]
# Validating:  47%|████▋     | 15/32 [00:12<00:13,  1.22it/s]
# Epoch 0:  95%|█████████▍| 64030/67616 [13:13:50<44:27,  1.34it/s, loss=480, v_num=flco]
# Validating:  53%|█████▎    | 17/32 [00:13<00:12,  1.21it/s]
# Epoch 0:  95%|█████████▍| 64032/67616 [13:13:51<44:26,  1.34it/s, loss=480, v_num=flco]
# Validating:  59%|█████▉    | 19/32 [00:14<00:09,  1.42it/s]
# Epoch 0:  95%|█████████▍| 64034/67616 [13:13:53<44:24,  1.34it/s, loss=480, v_num=flco]
# Validating:  66%|██████▌   | 21/32 [00:16<00:07,  1.45it/s]
# Epoch 0:  95%|█████████▍| 64036/67616 [13:13:54<44:23,  1.34it/s, loss=480, v_num=flco]
# Validating:  72%|███████▏  | 23/32 [00:17<00:06,  1.41it/s]
# Epoch 0:  95%|█████████▍| 64038/67616 [13:13:56<44:21,  1.34it/s, loss=480, v_num=flco]
# Validating:  78%|███████▊  | 25/32 [00:18<00:04,  1.52it/s]
# Epoch 0:  95%|█████████▍| 64040/67616 [13:13:57<44:20,  1.34it/s, loss=480, v_num=flco]
# Validating:  84%|████████▍ | 27/32 [00:20<00:03,  1.32it/s]
# Epoch 0:  95%|█████████▍| 64042/67616 [13:13:58<44:18,  1.34it/s, loss=480, v_num=flco]
# Validating:  91%|█████████ | 29/32 [00:21<00:01,  1.57it/s]
# Epoch 0:  95%|█████████▍| 64044/67616 [13:14:00<44:17,  1.34it/s, loss=480, v_num=flco]
# Validating:  97%|█████████▋| 31/32 [00:23<00:00,  1.46it/s]
# Epoch 0:  95%|█████████▍| 64046/67616 [13:14:01<44:15,  1.34it/s, loss=480, v_num=flco]
# Epoch 0:  96%|█████████▌| 65046/67616 [13:45:16<32:36,  1.31it/s, loss=481, v_num=flco]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/32 [00:00<?, ?it/s]
# Epoch 0:  96%|█████████▌| 65048/67616 [13:45:17<32:34,  1.31it/s, loss=481, v_num=flco]
# Validating:   6%|▋         | 2/32 [00:01<00:21,  1.41it/s]
# Epoch 0:  96%|█████████▌| 65050/67616 [13:45:18<32:33,  1.31it/s, loss=481, v_num=flco]
# Validating:  12%|█▎        | 4/32 [00:02<00:18,  1.53it/s]
# Epoch 0:  96%|█████████▌| 65052/67616 [13:45:19<32:31,  1.31it/s, loss=481, v_num=flco]
# Validating:  19%|█▉        | 6/32 [00:03<00:15,  1.68it/s]
# Epoch 0:  96%|█████████▌| 65054/67616 [13:45:20<32:30,  1.31it/s, loss=481, v_num=flco]
# Validating:  25%|██▌       | 8/32 [00:04<00:15,  1.54it/s]
# Epoch 0:  96%|█████████▌| 65056/67616 [13:45:21<32:28,  1.31it/s, loss=481, v_num=flco]
# Validating:  31%|███▏      | 10/32 [00:06<00:14,  1.51it/s]
# Epoch 0:  96%|█████████▌| 65058/67616 [13:45:23<32:27,  1.31it/s, loss=481, v_num=flco]
# Validating:  38%|███▊      | 12/32 [00:07<00:13,  1.49it/s]
# Epoch 0:  96%|█████████▌| 65060/67616 [13:45:25<32:25,  1.31it/s, loss=481, v_num=flco]
# Validating:  44%|████▍     | 14/32 [00:09<00:14,  1.24it/s]
# Epoch 0:  96%|█████████▌| 65062/67616 [13:45:26<32:24,  1.31it/s, loss=481, v_num=flco]
# Validating:  50%|█████     | 16/32 [00:10<00:11,  1.40it/s]
# Epoch 0:  96%|█████████▌| 65064/67616 [13:45:27<32:22,  1.31it/s, loss=481, v_num=flco]
# Validating:  56%|█████▋    | 18/32 [00:12<00:09,  1.45it/s]
# Epoch 0:  96%|█████████▌| 65066/67616 [13:45:29<32:21,  1.31it/s, loss=481, v_num=flco]
# Validating:  62%|██████▎   | 20/32 [00:13<00:09,  1.28it/s]
# Epoch 0:  96%|█████████▌| 65068/67616 [13:45:31<32:19,  1.31it/s, loss=481, v_num=flco]
# Validating:  69%|██████▉   | 22/32 [00:15<00:07,  1.40it/s]
# Epoch 0:  96%|█████████▌| 65070/67616 [13:45:32<32:18,  1.31it/s, loss=481, v_num=flco]
# Validating:  75%|███████▌  | 24/32 [00:16<00:06,  1.30it/s]
# Epoch 0:  96%|█████████▌| 65072/67616 [13:45:34<32:16,  1.31it/s, loss=481, v_num=flco]
# Validating:  81%|████████▏ | 26/32 [00:18<00:04,  1.29it/s]
# Epoch 0:  96%|█████████▌| 65074/67616 [13:45:35<32:15,  1.31it/s, loss=481, v_num=flco]
# Validating:  88%|████████▊ | 28/32 [00:19<00:02,  1.42it/s]
# Epoch 0:  96%|█████████▌| 65076/67616 [13:45:36<32:13,  1.31it/s, loss=481, v_num=flco]
# Validating:  94%|█████████▍| 30/32 [00:21<00:01,  1.37it/s]
# Epoch 0:  96%|█████████▌| 65078/67616 [13:45:38<32:11,  1.31it/s, loss=481, v_num=flco]
# Epoch 0:  96%|█████████▌| 65079/67616 [13:45:38<32:11,  1.31it/s, loss=481, v_num=flco]
# Epoch 0:  97%|█████████▋| 65450/67616 [13:53:02<27:34,  1.31it/s, loss=478, v_num=flco]
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   warnings.warn(*args, **kwargs)
# Saving latest checkpoint...
# Epoch 0:  97%|█████████▋| 65450/67616 [13:53:02<27:34,  1.31it/s, loss=478, v_num=flco]
# (ContrastiveTrainModule(
#    (metrics): ThresholdedMetrics()
#    (model): EncoderPredictor(
#      (inp_query_layer): Sequential(
#        (scaled_embed): ScaledEmbedding(
#          (embedding): Embedding(17, 65)
#        )
#        (position_encoder): LearnedPositionEncoder()
#        (embed_dropout): Dropout(p=0.0, inplace=False)
#      )
#      (inp_key_layer): Sequential(
#        (scaled_embed): ScaledEmbedding(
#          (embedding): Embedding(17, 65)
#        )
#        (position_encoder): LearnedPositionEncoder()
#        (embed_dropout): Dropout(p=0.0, inplace=False)
#      )
#      (query_encoder): Encoder(
#        (encoder_layers): ModuleList(
#          (0): EncoderLayer(
#            (poswise_ff): Positiontwise_FF(
#              (linear1): Linear(in_features=65, out_features=1024, bias=True)
#              (linear2): Linear(in_features=1024, out_features=65, bias=True)
#            )
#            (self_attn): MultiHeadAttention(
#              (attn_wt_dropout): Dropout(p=0.0, inplace=False)
#              (projections_QKVO): ModuleList(
#                (0): Linear(in_features=65, out_features=65, bias=True)
#                (1): Linear(in_features=65, out_features=65, bias=True)
#                (2): Linear(in_features=65, out_features=65, bias=True)
#                (3): Linear(in_features=65, out_features=65, bias=True)
#              )
#            )
#            (layer_norms): ModuleList(
#              (0): LayerNorm()
#              (1): LayerNorm()
#            )
#            (heads_dropout): Dropout(p=0.0, inplace=False)
#            (pff_dropout): Dropout(p=0.0, inplace=False)
#          )
#          (1): EncoderLayer(
#            (poswise_ff): Positiontwise_FF(
#              (linear1): Linear(in_features=65, out_features=1024, bias=True)
#              (linear2): Linear(in_features=1024, out_features=65, bias=True)
#            )
#            (self_attn): MultiHeadAttention(
#              (attn_wt_dropout): Dropout(p=0.0, inplace=False)
#              (projections_QKVO): ModuleList(
#                (0): Linear(in_features=65, out_features=65, bias=True)
#                (1): Linear(in_features=65, out_features=65, bias=True)
#                (2): Linear(in_features=65, out_features=65, bias=True)
#                (3): Linear(in_features=65, out_features=65, bias=True)
#              )
#            )
#            (layer_norms): ModuleList(
#              (0): LayerNorm()
#              (1): LayerNorm()
#            )
#            (heads_dropout): Dropout(p=0.0, inplace=False)
#            (pff_dropout): Dropout(p=0.0, inplace=False)
#          )
#        )
#      )
#      (key_encoder): Encoder(
#        (encoder_layers): ModuleList(
#          (0): EncoderLayer(
#            (poswise_ff): Positiontwise_FF(
#              (linear1): Linear(in_features=65, out_features=1024, bias=True)
#              (linear2): Linear(in_features=1024, out_features=65, bias=True)
#            )
#            (self_attn): MultiHeadAttention(
#              (attn_wt_dropout): Dropout(p=0.0, inplace=False)
#              (projections_QKVO): ModuleList(
#                (0): Linear(in_features=65, out_features=65, bias=True)
#                (1): Linear(in_features=65, out_features=65, bias=True)
#                (2): Linear(in_features=65, out_features=65, bias=True)
#                (3): Linear(in_features=65, out_features=65, bias=True)
#              )
#            )
#            (layer_norms): ModuleList(
#              (0): LayerNorm()
#              (1): LayerNorm()
#            )
#            (heads_dropout): Dropout(p=0.0, inplace=False)
#            (pff_dropout): Dropout(p=0.0, inplace=False)
#          )
#          (1): EncoderLayer(
#            (poswise_ff): Positiontwise_FF(
#              (linear1): Linear(in_features=65, out_features=1024, bias=True)
#              (linear2): Linear(in_features=1024, out_features=65, bias=True)
#            )
#            (self_attn): MultiHeadAttention(
#              (attn_wt_dropout): Dropout(p=0.0, inplace=False)
#              (projections_QKVO): ModuleList(
#                (0): Linear(in_features=65, out_features=65, bias=True)
#                (1): Linear(in_features=65, out_features=65, bias=True)
#                (2): Linear(in_features=65, out_features=65, bias=True)
#                (3): Linear(in_features=65, out_features=65, bias=True)
#              )
#            )
#            (layer_norms): ModuleList(
#              (0): LayerNorm()
#              (1): LayerNorm()
#            )
#            (heads_dropout): Dropout(p=0.0, inplace=False)
#            (pff_dropout): Dropout(p=0.0, inplace=False)
#          )
#        )
#      )
#    )
#    (loss_criterion): InfoCELoss(
#      (CE_loss): CrossEntropyLoss()
#    )
#    (softmax): Softmax(dim=1)
#  ),
#  <datamodule.GameDataModule at 0x7f55a21c2400>)
