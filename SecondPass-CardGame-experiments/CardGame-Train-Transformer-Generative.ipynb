# %%
# https://discuss.pytorch.org/t/i-have-3-gpu-why-torch-cuda-device-count-only-return-1/7245/4
import torch
import sys
print('__Python VERSION:', sys.version)
print('__pyTorch VERSION:', torch.__version__)
print('__CUDA VERSION')
from subprocess import call
# call(["nvcc", "--version"]) does not work
! nvcc --version
print('__CUDNN VERSION:', torch.backends.cudnn.version())
print('__Number CUDA Devices:', torch.cuda.device_count())
print('__Devices')
call(["nvidia-smi", "--format=csv", "--query-gpu=index,name,driver_version,memory.total,memory.used,memory.free"])
print('Active CUDA Device: GPU', torch.cuda.current_device())

print ('Available devices ', torch.cuda.device_count())
print ('Current cuda device ', torch.cuda.current_device())
# Out:
# __Python VERSION: 3.8.3 (default, May 19 2020, 18:47:26)
# [GCC 7.3.0]
# __pyTorch VERSION: 1.7.0
# __CUDA VERSION
# /usr/bin/sh: 1: nvcc: not found
# __CUDNN VERSION: 8003
# __Number CUDA Devices: 2
# __Devices
# Active CUDA Device: GPU 0
# Available devices  2
# Current cuda device  0

# %%
# %load_ext autoreload
# %autoreload 2

import os
import json
import main
import random
from argparse import ArgumentDefaultsHelpFormatter, ArgumentParser
# Out:
# wandb: Currently logged in as: chucooleg (use `wandb login --relogin` to force relogin)

# %%
# arguments
parser = ArgumentParser(formatter_class=ArgumentDefaultsHelpFormatter)
args = parser.parse_args('')

# args.data_path = '../Raw_Datasets/SET/4Attr-3Vals-2NestDepth-2CardsPerQ-Full-6561Train-6561Val.json'
args.data_path = '../Raw_Datasets/SimpleShatter/SimpleShatter-Full-1Train-10Val.json'
args.config_path = 'config.json'
args.generate_full_matrix = True
args.checkpoint_dir = 'checkpoints'
args.mode = 'train'
args.gpu = 1
args.approve_before_training = False

# %%
trainmodule, game_datamodule = main.main(args)
# Out:
# Global seed set to 42
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: Checkpoint directory checkpoints/ContrastiveLearning-cardgame-Debug-Shattering/20210307-031918-SET;attr1-val10-nest1;generative;embedByProperty;d_model32;dot-product;params426.72K exists and is not empty.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# ---------data----------
# num_attributes : 1
# num_attr_vals : 10
# num_cards_per_query : 10
# nest_depth_int : 1
# key_support_size : 11
# query_support_size : 1024
# max_len_q : 10
# len_k : 1
# hold_out : False
# train_datapoints length : 5121
# val_datapoints length : 5121
# train_tokens length : 5121
# val_tokens length : 5121
# sparsity_estimate : 0.45463423295454547
# vocab_size : 18
# ( : 11
# ) : 12
# NULL : 13
# SEP : 14
# SOS : 15
# EOS : 16
# PAD : 17
# -----------------------
# ----------hparams----------
# seed : 42
# batch_size : 512
# max_epochs : 1
# d_model : 32
# embed_dropout : 0.0
# model : generative
# embedding_by_property : True
# encoder : transformer
# decoder : transformer
# d_ff : 1024
# num_heads : 1
# N_enc : 6
# N_dec : 6
# attn_wt_tying_scheme : untie_QKVO
# attn_wt_dropout : 0.0
# heads_dropout : 0.0
# pff_dropout : 0.0
# representation_pos : 0
# dotproduct_bottleneck : True
# normalize_dotproduct : True
# contrastive_use_infoNCE : True
# loss_temperature_const : 1.0
# loss_smoothing_const : 0.1
# nonlinear_classifier_scale_down_factor : [2, 1]
# adam_lr : 0.001
# adam_beta1 : 0.9
# adam_beta2 : 0.999
# adam_epsilon : 1e-08
# adam_weight_decay : 0
# sgd_lr : 0.001
# sgd_momentum : 0
# scheduled_adam_beta1 : 0.9
# scheduled_adam_beta2 : 0.98
# scheduled_adam_epsilon : 1e-09
# scheduled_adam_warmup_steps : 12000
# additional_lr_decay : True
# additional_lr_decay_milestones : [12000, 12500, 13000, 13500, 14000, 14500, 15000, 15500, 16000, 16500, 17000, 17500, 18000]
# additional_lr_decay_gamma : 0.9
# gradient_clip_val : 0
# debug : False
# key_support_size : 11
# query_support_size : 1024
# num_attributes : 1
# num_attr_vals : 10
# num_cards_per_query : 10
# nest_depth_int : 1
# vocab_size : 18
# ( : 11
# ) : 12
# NULL : 13
# SEP : 14
# SOS : 15
# EOS : 16
# PAD : 17
# hold_out : False
# populate_logits_matrix : True
# max_len_q : 12
# len_k : 3
# ---------------------------
# Generating Full Matrix of Size 11 by 1024 = 11264
# Generating Full Matrix
# {'num_keys': 11, 'num_queries': 1024, 'tot_size': 11264, 'shape': (11, 1024), 'sparsity': 0.45463423295454547, 'xy_rank': 11, 'xy_div_xyind_rank': 11}
#     | Name                                                                 | Type                   | Params
# ------------------------------------------------------------------------------------------------------------------
# 0   | metrics                                                              | ThresholdedMetrics     | 0
# 1   | model                                                                | DecoderPredictor       | 426 K
# 2   | model.inp_querykey_layer                                             | Sequential             | 1.1 K
# 3   | model.inp_querykey_layer.scaled_embed                                | ScaledEmbedding        | 576
# 4   | model.inp_querykey_layer.scaled_embed.embedding                      | Embedding              | 576
# 5   | model.inp_querykey_layer.position_encoder                            | LearnedPositionEncoder | 480
# 6   | model.inp_querykey_layer.embed_dropout                               | Dropout                | 0
# 7   | model.querykey_decoder                                               | Encoder                | 425 K
# 8   | model.querykey_decoder.encoder_layers                                | ModuleList             | 425 K
# 9   | model.querykey_decoder.encoder_layers.0                              | EncoderLayer           | 70.9 K
# 10  | model.querykey_decoder.encoder_layers.0.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 11  | model.querykey_decoder.encoder_layers.0.poswise_ff.linear1           | Linear                 | 33.8 K
# 12  | model.querykey_decoder.encoder_layers.0.poswise_ff.linear2           | Linear                 | 32.8 K
# 13  | model.querykey_decoder.encoder_layers.0.self_attn                    | MultiHeadAttention     | 4.2 K
# 14  | model.querykey_decoder.encoder_layers.0.self_attn.attn_wt_dropout    | Dropout                | 0
# 15  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 16  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 17  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 18  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 19  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 20  | model.querykey_decoder.encoder_layers.0.layer_norms                  | ModuleList             | 128
# 21  | model.querykey_decoder.encoder_layers.0.layer_norms.0                | LayerNorm              | 64
# 22  | model.querykey_decoder.encoder_layers.0.layer_norms.1                | LayerNorm              | 64
# 23  | model.querykey_decoder.encoder_layers.0.heads_dropout                | Dropout                | 0
# 24  | model.querykey_decoder.encoder_layers.0.pff_dropout                  | Dropout                | 0
# 25  | model.querykey_decoder.encoder_layers.1                              | EncoderLayer           | 70.9 K
# 26  | model.querykey_decoder.encoder_layers.1.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 27  | model.querykey_decoder.encoder_layers.1.poswise_ff.linear1           | Linear                 | 33.8 K
# 28  | model.querykey_decoder.encoder_layers.1.poswise_ff.linear2           | Linear                 | 32.8 K
# 29  | model.querykey_decoder.encoder_layers.1.self_attn                    | MultiHeadAttention     | 4.2 K
# 30  | model.querykey_decoder.encoder_layers.1.self_attn.attn_wt_dropout    | Dropout                | 0
# 31  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 32  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 33  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 34  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 35  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 36  | model.querykey_decoder.encoder_layers.1.layer_norms                  | ModuleList             | 128
# 37  | model.querykey_decoder.encoder_layers.1.layer_norms.0                | LayerNorm              | 64
# 38  | model.querykey_decoder.encoder_layers.1.layer_norms.1                | LayerNorm              | 64
# 39  | model.querykey_decoder.encoder_layers.1.heads_dropout                | Dropout                | 0
# 40  | model.querykey_decoder.encoder_layers.1.pff_dropout                  | Dropout                | 0
# 41  | model.querykey_decoder.encoder_layers.2                              | EncoderLayer           | 70.9 K
# 42  | model.querykey_decoder.encoder_layers.2.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 43  | model.querykey_decoder.encoder_layers.2.poswise_ff.linear1           | Linear                 | 33.8 K
# 44  | model.querykey_decoder.encoder_layers.2.poswise_ff.linear2           | Linear                 | 32.8 K
# 45  | model.querykey_decoder.encoder_layers.2.self_attn                    | MultiHeadAttention     | 4.2 K
# 46  | model.querykey_decoder.encoder_layers.2.self_attn.attn_wt_dropout    | Dropout                | 0
# 47  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 48  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 49  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 50  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 51  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 52  | model.querykey_decoder.encoder_layers.2.layer_norms                  | ModuleList             | 128
# 53  | model.querykey_decoder.encoder_layers.2.layer_norms.0                | LayerNorm              | 64
# 54  | model.querykey_decoder.encoder_layers.2.layer_norms.1                | LayerNorm              | 64
# 55  | model.querykey_decoder.encoder_layers.2.heads_dropout                | Dropout                | 0
# 56  | model.querykey_decoder.encoder_layers.2.pff_dropout                  | Dropout                | 0
# 57  | model.querykey_decoder.encoder_layers.3                              | EncoderLayer           | 70.9 K
# 58  | model.querykey_decoder.encoder_layers.3.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 59  | model.querykey_decoder.encoder_layers.3.poswise_ff.linear1           | Linear                 | 33.8 K
# 60  | model.querykey_decoder.encoder_layers.3.poswise_ff.linear2           | Linear                 | 32.8 K
# 61  | model.querykey_decoder.encoder_layers.3.self_attn                    | MultiHeadAttention     | 4.2 K
# 62  | model.querykey_decoder.encoder_layers.3.self_attn.attn_wt_dropout    | Dropout                | 0
# 63  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 64  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 65  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 66  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 67  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 68  | model.querykey_decoder.encoder_layers.3.layer_norms                  | ModuleList             | 128
# 69  | model.querykey_decoder.encoder_layers.3.layer_norms.0                | LayerNorm              | 64
# 70  | model.querykey_decoder.encoder_layers.3.layer_norms.1                | LayerNorm              | 64
# 71  | model.querykey_decoder.encoder_layers.3.heads_dropout                | Dropout                | 0
# 72  | model.querykey_decoder.encoder_layers.3.pff_dropout                  | Dropout                | 0
# 73  | model.querykey_decoder.encoder_layers.4                              | EncoderLayer           | 70.9 K
# 74  | model.querykey_decoder.encoder_layers.4.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 75  | model.querykey_decoder.encoder_layers.4.poswise_ff.linear1           | Linear                 | 33.8 K
# 76  | model.querykey_decoder.encoder_layers.4.poswise_ff.linear2           | Linear                 | 32.8 K
# 77  | model.querykey_decoder.encoder_layers.4.self_attn                    | MultiHeadAttention     | 4.2 K
# 78  | model.querykey_decoder.encoder_layers.4.self_attn.attn_wt_dropout    | Dropout                | 0
# 79  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 80  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 81  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 82  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 83  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 84  | model.querykey_decoder.encoder_layers.4.layer_norms                  | ModuleList             | 128
# 85  | model.querykey_decoder.encoder_layers.4.layer_norms.0                | LayerNorm              | 64
# 86  | model.querykey_decoder.encoder_layers.4.layer_norms.1                | LayerNorm              | 64
# 87  | model.querykey_decoder.encoder_layers.4.heads_dropout                | Dropout                | 0
# 88  | model.querykey_decoder.encoder_layers.4.pff_dropout                  | Dropout                | 0
# 89  | model.querykey_decoder.encoder_layers.5                              | EncoderLayer           | 70.9 K
# 90  | model.querykey_decoder.encoder_layers.5.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 91  | model.querykey_decoder.encoder_layers.5.poswise_ff.linear1           | Linear                 | 33.8 K
# 92  | model.querykey_decoder.encoder_layers.5.poswise_ff.linear2           | Linear                 | 32.8 K
# 93  | model.querykey_decoder.encoder_layers.5.self_attn                    | MultiHeadAttention     | 4.2 K
# 94  | model.querykey_decoder.encoder_layers.5.self_attn.attn_wt_dropout    | Dropout                | 0
# 95  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 96  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 97  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 98  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 99  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 100 | model.querykey_decoder.encoder_layers.5.layer_norms                  | ModuleList             | 128
# 101 | model.querykey_decoder.encoder_layers.5.layer_norms.0                | LayerNorm              | 64
# 102 | model.querykey_decoder.encoder_layers.5.layer_norms.1                | LayerNorm              | 64
# 103 | model.querykey_decoder.encoder_layers.5.heads_dropout                | Dropout                | 0
# 104 | model.querykey_decoder.encoder_layers.5.pff_dropout                  | Dropout                | 0
# 105 | model.classifier                                                     | Classifier             | 576
# 106 | logsoftmax                                                           | LogSoftmax             | 0
# 107 | softmax                                                              | Softmax                | 0
# 108 | loss_criterion                                                       | LabelSmoothedLoss      | 0
# 109 | loss_criterion.KLdiv_criterion                                       | KLDivLoss              | 0
# 110 | loss_criterion.logprob                                               | LogSoftmax             | 0
# ------------------------------------------------------------------------------------------------------------------
# 426 K     Trainable params
# 0         Non-trainable params
# 426 K     Total params
# 1.707     Total estimated model params size (MB)
#
# RUN NAME :
#  SET;attr1-val10-nest1;generative;embedByProperty;d_model32;dot-product;params426.72K
# Checkpoint Path:
#  checkpoints/ContrastiveLearning-cardgame-Debug-Shattering/20210307-031918-SET;attr1-val10-nest1;generative;embedByProperty;d_model32;dot-product;params426.72K
# /app/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/main.py:220: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   with torch.autograd.detect_anomaly():
# wandb: wandb version 0.10.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.20<br/>
#                 Syncing run <strong style="color:#cdcd00">SET;attr1-val10-nest1;generative;embedByProperty;d_model32;dot-product;params426.72K</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Debug-Shattering" target="_blank">https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Debug-Shattering</a><br/>
#                 Run page: <a href="https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Debug-Shattering/runs/6siu975g" target="_blank">https://wandb.ai/chucooleg/ContrastiveLearning-cardgame-Debug-Shattering/runs/6siu975g</a><br/>
#                 Run data is saved locally in <code>/app/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/wandb/run-20210307_031921-6siu975g</code><br/><br/>
#     | Name                                                                 | Type                   | Params
# ------------------------------------------------------------------------------------------------------------------
# 0   | metrics                                                              | ThresholdedMetrics     | 0
# 1   | model                                                                | DecoderPredictor       | 426 K
# 2   | model.inp_querykey_layer                                             | Sequential             | 1.1 K
# 3   | model.inp_querykey_layer.scaled_embed                                | ScaledEmbedding        | 576
# 4   | model.inp_querykey_layer.scaled_embed.embedding                      | Embedding              | 576
# 5   | model.inp_querykey_layer.position_encoder                            | LearnedPositionEncoder | 480
# 6   | model.inp_querykey_layer.embed_dropout                               | Dropout                | 0
# 7   | model.querykey_decoder                                               | Encoder                | 425 K
# 8   | model.querykey_decoder.encoder_layers                                | ModuleList             | 425 K
# 9   | model.querykey_decoder.encoder_layers.0                              | EncoderLayer           | 70.9 K
# 10  | model.querykey_decoder.encoder_layers.0.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 11  | model.querykey_decoder.encoder_layers.0.poswise_ff.linear1           | Linear                 | 33.8 K
# 12  | model.querykey_decoder.encoder_layers.0.poswise_ff.linear2           | Linear                 | 32.8 K
# 13  | model.querykey_decoder.encoder_layers.0.self_attn                    | MultiHeadAttention     | 4.2 K
# 14  | model.querykey_decoder.encoder_layers.0.self_attn.attn_wt_dropout    | Dropout                | 0
# 15  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 16  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 17  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 18  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 19  | model.querykey_decoder.encoder_layers.0.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 20  | model.querykey_decoder.encoder_layers.0.layer_norms                  | ModuleList             | 128
# 21  | model.querykey_decoder.encoder_layers.0.layer_norms.0                | LayerNorm              | 64
# 22  | model.querykey_decoder.encoder_layers.0.layer_norms.1                | LayerNorm              | 64
# 23  | model.querykey_decoder.encoder_layers.0.heads_dropout                | Dropout                | 0
# 24  | model.querykey_decoder.encoder_layers.0.pff_dropout                  | Dropout                | 0
# 25  | model.querykey_decoder.encoder_layers.1                              | EncoderLayer           | 70.9 K
# 26  | model.querykey_decoder.encoder_layers.1.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 27  | model.querykey_decoder.encoder_layers.1.poswise_ff.linear1           | Linear                 | 33.8 K
# 28  | model.querykey_decoder.encoder_layers.1.poswise_ff.linear2           | Linear                 | 32.8 K
# 29  | model.querykey_decoder.encoder_layers.1.self_attn                    | MultiHeadAttention     | 4.2 K
# 30  | model.querykey_decoder.encoder_layers.1.self_attn.attn_wt_dropout    | Dropout                | 0
# 31  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 32  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 33  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 34  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 35  | model.querykey_decoder.encoder_layers.1.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 36  | model.querykey_decoder.encoder_layers.1.layer_norms                  | ModuleList             | 128
# 37  | model.querykey_decoder.encoder_layers.1.layer_norms.0                | LayerNorm              | 64
# 38  | model.querykey_decoder.encoder_layers.1.layer_norms.1                | LayerNorm              | 64
# 39  | model.querykey_decoder.encoder_layers.1.heads_dropout                | Dropout                | 0
# 40  | model.querykey_decoder.encoder_layers.1.pff_dropout                  | Dropout                | 0
# 41  | model.querykey_decoder.encoder_layers.2                              | EncoderLayer           | 70.9 K
# 42  | model.querykey_decoder.encoder_layers.2.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 43  | model.querykey_decoder.encoder_layers.2.poswise_ff.linear1           | Linear                 | 33.8 K
# 44  | model.querykey_decoder.encoder_layers.2.poswise_ff.linear2           | Linear                 | 32.8 K
# 45  | model.querykey_decoder.encoder_layers.2.self_attn                    | MultiHeadAttention     | 4.2 K
# 46  | model.querykey_decoder.encoder_layers.2.self_attn.attn_wt_dropout    | Dropout                | 0
# 47  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 48  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 49  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 50  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 51  | model.querykey_decoder.encoder_layers.2.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 52  | model.querykey_decoder.encoder_layers.2.layer_norms                  | ModuleList             | 128
# 53  | model.querykey_decoder.encoder_layers.2.layer_norms.0                | LayerNorm              | 64
# 54  | model.querykey_decoder.encoder_layers.2.layer_norms.1                | LayerNorm              | 64
# 55  | model.querykey_decoder.encoder_layers.2.heads_dropout                | Dropout                | 0
# 56  | model.querykey_decoder.encoder_layers.2.pff_dropout                  | Dropout                | 0
# 57  | model.querykey_decoder.encoder_layers.3                              | EncoderLayer           | 70.9 K
# 58  | model.querykey_decoder.encoder_layers.3.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 59  | model.querykey_decoder.encoder_layers.3.poswise_ff.linear1           | Linear                 | 33.8 K
# 60  | model.querykey_decoder.encoder_layers.3.poswise_ff.linear2           | Linear                 | 32.8 K
# 61  | model.querykey_decoder.encoder_layers.3.self_attn                    | MultiHeadAttention     | 4.2 K
# 62  | model.querykey_decoder.encoder_layers.3.self_attn.attn_wt_dropout    | Dropout                | 0
# 63  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 64  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 65  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 66  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 67  | model.querykey_decoder.encoder_layers.3.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 68  | model.querykey_decoder.encoder_layers.3.layer_norms                  | ModuleList             | 128
# 69  | model.querykey_decoder.encoder_layers.3.layer_norms.0                | LayerNorm              | 64
# 70  | model.querykey_decoder.encoder_layers.3.layer_norms.1                | LayerNorm              | 64
# 71  | model.querykey_decoder.encoder_layers.3.heads_dropout                | Dropout                | 0
# 72  | model.querykey_decoder.encoder_layers.3.pff_dropout                  | Dropout                | 0
# 73  | model.querykey_decoder.encoder_layers.4                              | EncoderLayer           | 70.9 K
# 74  | model.querykey_decoder.encoder_layers.4.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 75  | model.querykey_decoder.encoder_layers.4.poswise_ff.linear1           | Linear                 | 33.8 K
# 76  | model.querykey_decoder.encoder_layers.4.poswise_ff.linear2           | Linear                 | 32.8 K
# 77  | model.querykey_decoder.encoder_layers.4.self_attn                    | MultiHeadAttention     | 4.2 K
# 78  | model.querykey_decoder.encoder_layers.4.self_attn.attn_wt_dropout    | Dropout                | 0
# 79  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 80  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 81  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 82  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 83  | model.querykey_decoder.encoder_layers.4.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 84  | model.querykey_decoder.encoder_layers.4.layer_norms                  | ModuleList             | 128
# 85  | model.querykey_decoder.encoder_layers.4.layer_norms.0                | LayerNorm              | 64
# 86  | model.querykey_decoder.encoder_layers.4.layer_norms.1                | LayerNorm              | 64
# 87  | model.querykey_decoder.encoder_layers.4.heads_dropout                | Dropout                | 0
# 88  | model.querykey_decoder.encoder_layers.4.pff_dropout                  | Dropout                | 0
# 89  | model.querykey_decoder.encoder_layers.5                              | EncoderLayer           | 70.9 K
# 90  | model.querykey_decoder.encoder_layers.5.poswise_ff                   | Positiontwise_FF       | 66.6 K
# 91  | model.querykey_decoder.encoder_layers.5.poswise_ff.linear1           | Linear                 | 33.8 K
# 92  | model.querykey_decoder.encoder_layers.5.poswise_ff.linear2           | Linear                 | 32.8 K
# 93  | model.querykey_decoder.encoder_layers.5.self_attn                    | MultiHeadAttention     | 4.2 K
# 94  | model.querykey_decoder.encoder_layers.5.self_attn.attn_wt_dropout    | Dropout                | 0
# 95  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO   | ModuleList             | 4.2 K
# 96  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.0 | Linear                 | 1.1 K
# 97  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.1 | Linear                 | 1.1 K
# 98  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.2 | Linear                 | 1.1 K
# 99  | model.querykey_decoder.encoder_layers.5.self_attn.projections_QKVO.3 | Linear                 | 1.1 K
# 100 | model.querykey_decoder.encoder_layers.5.layer_norms                  | ModuleList             | 128
# 101 | model.querykey_decoder.encoder_layers.5.layer_norms.0                | LayerNorm              | 64
# 102 | model.querykey_decoder.encoder_layers.5.layer_norms.1                | LayerNorm              | 64
# 103 | model.querykey_decoder.encoder_layers.5.heads_dropout                | Dropout                | 0
# 104 | model.querykey_decoder.encoder_layers.5.pff_dropout                  | Dropout                | 0
# 105 | model.classifier                                                     | Classifier             | 576
# 106 | logsoftmax                                                           | LogSoftmax             | 0
# 107 | softmax                                                              | Softmax                | 0
# 108 | loss_criterion                                                       | LabelSmoothedLoss      | 0
# 109 | loss_criterion.KLdiv_criterion                                       | KLDivLoss              | 0
# 110 | loss_criterion.logprob                                               | LogSoftmax             | 0
# ------------------------------------------------------------------------------------------------------------------
# 426 K     Trainable params
# 0         Non-trainable params
# 426 K     Total params
# 1.707     Total estimated model params size (MB)
# Validation sanity check:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# /app/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/dataset.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gt_binary_tensor = torch.tensor(gt_binary).long()
# Validation sanity check:  50%|█████     | 1/2 [00:01<00:01,  1.06s/it]
# /home/user/miniconda/lib/python3.8/site-packages/torch/cuda/memory.py:231: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# Epoch 0:   0%|          | 0/22 [00:00<?, ?it/s]
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The validation_epoch_end should not return anything as of 9.1. To log, use self.log(...) or self.write(...) directly in the LightningModule
#   warnings.warn(*args, **kwargs)
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: RuntimeWarning: You are using `LearningRateMonitor` callback with models that have no learning rate schedulers. Please see documentation for `configure_optimizers` method.
#   warnings.warn(*args, **kwargs)
# Epoch 0:  50%|█████     | 11/22 [00:12<00:12,  1.13s/it, loss=2.64e+04, v_num=975g]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/11 [00:00<?, ?it/s]
# Epoch 0:  59%|█████▉    | 13/22 [00:12<00:08,  1.02it/s, loss=2.64e+04, v_num=975g]
# Validating:  18%|█▊        | 2/11 [00:00<00:02,  3.28it/s]
# Epoch 0:  68%|██████▊   | 15/22 [00:13<00:06,  1.12it/s, loss=2.64e+04, v_num=975g]
# Validating:  36%|███▋      | 4/11 [00:01<00:02,  3.18it/s]
# Epoch 0:  77%|███████▋  | 17/22 [00:14<00:04,  1.21it/s, loss=2.64e+04, v_num=975g]
# Validating:  55%|█████▍    | 6/11 [00:01<00:01,  3.18it/s]
# Epoch 0:  86%|████████▋ | 19/22 [00:14<00:02,  1.30it/s, loss=2.64e+04, v_num=975g]
# Validating:  73%|███████▎  | 8/11 [00:02<00:00,  3.23it/s]
# Epoch 0:  95%|█████████▌| 21/22 [00:15<00:00,  1.38it/s, loss=2.64e+04, v_num=975g]
# Validating:  91%|█████████ | 10/11 [00:03<00:00,  3.23it/s]
# Epoch 0: 100%|██████████| 22/22 [00:15<00:00,  1.39it/s, loss=2.64e+04, v_num=975g]
# Saving latest checkpoint...
# Epoch 0: 100%|██████████| 22/22 [00:16<00:00,  1.37it/s, loss=2.64e+04, v_num=975g]
# Profiler Report
#
# Action                             	|  Mean duration (s)	|Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------
# Total                              	|  -              	|_              	|  21.072         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------
# run_training_epoch                 	|  16.042         	|1              	|  16.042         	|  76.129         	|
# run_training_batch                 	|  1.1156         	|11             	|  12.271         	|  58.234         	|
# optimizer_step_and_closure_0       	|  1.1144         	|11             	|  12.259         	|  58.174         	|
# training_step_and_backward         	|  1.1056         	|11             	|  12.162         	|  57.715         	|
# model_backward                     	|  0.83573        	|11             	|  9.1931         	|  43.626         	|
# evaluation_step_and_end            	|  0.33865        	|13             	|  4.4025         	|  20.892         	|
# validation_step                    	|  0.33843        	|13             	|  4.3996         	|  20.879         	|
# model_forward                      	|  0.26516        	|11             	|  2.9168         	|  13.842         	|
# training_step                      	|  0.26488        	|11             	|  2.9137         	|  13.827         	|
# get_train_batch                    	|  0.012527       	|11             	|  0.1378         	|  0.65393        	|
# on_before_accelerator_backend_setup	|  0.071061       	|1              	|  0.071061       	|  0.33722        	|
# on_validation_end                  	|  0.028403       	|2              	|  0.056806       	|  0.26958        	|
# on_train_end                       	|  0.039158       	|1              	|  0.039158       	|  0.18583        	|
# on_validation_batch_end            	|  0.0025681      	|13             	|  0.033385       	|  0.15843        	|
# on_train_batch_end                 	|  0.0021         	|11             	|  0.0231         	|  0.10962        	|
# on_validation_start                	|  0.0018488      	|2              	|  0.0036977      	|  0.017548       	|
# cache_result                       	|  2.6432e-05     	|113            	|  0.0029869      	|  0.014174       	|
# on_train_start                     	|  0.0026248      	|1              	|  0.0026248      	|  0.012456       	|
# on_epoch_start                     	|  0.00111        	|1              	|  0.00111        	|  0.0052675      	|
# on_after_backward                  	|  2.9594e-05     	|11             	|  0.00032553     	|  0.0015448      	|
# on_batch_start                     	|  2.4907e-05     	|11             	|  0.00027398     	|  0.0013002      	|
# on_validation_batch_start          	|  2.0466e-05     	|13             	|  0.00026605     	|  0.0012626      	|
# on_before_zero_grad                	|  2.22e-05       	|11             	|  0.0002442      	|  0.0011589      	|
# on_batch_end                       	|  1.7714e-05     	|11             	|  0.00019486     	|  0.00092472     	|
# on_train_batch_start               	|  1.6916e-05     	|11             	|  0.00018607     	|  0.00088302     	|
# validation_step_end                	|  1.2207e-05     	|13             	|  0.00015869     	|  0.00075307     	|
# training_step_end                  	|  1.1702e-05     	|11             	|  0.00012873     	|  0.00061087     	|
# on_validation_epoch_end            	|  2.5148e-05     	|2              	|  5.0295e-05     	|  0.00023868     	|
# on_epoch_end                       	|  1.2677e-05     	|3              	|  3.8032e-05     	|  0.00018048     	|
# on_fit_start                       	|  3.4335e-05     	|1              	|  3.4335e-05     	|  0.00016294     	|
# on_validation_epoch_start          	|  1.3035e-05     	|2              	|  2.6069e-05     	|  0.00012371     	|
# on_train_epoch_start               	|  2.0368e-05     	|1              	|  2.0368e-05     	|  9.6658e-05     	|
# on_train_epoch_end                 	|  1.8705e-05     	|1              	|  1.8705e-05     	|  8.8766e-05     	|

# %%
import pytorch_lightning as pl
from torch.utils.data import DataLoader
trainer = pl.Trainer(
    gpus=[1],
    min_epochs=1, max_epochs=1, 
    precision=32, 
    log_gpu_memory='all',
    weights_summary = 'full',
    gradient_clip_val=0.0,
)
# Out:
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores

# %%
from dataset import GameTestFullDataset
game_data = main.load_data(args.data_path)
test_loader = DataLoader(
    GameTestFullDataset(
        raw_data=game_data, embedding_by_property=False ,debug=True
    ))
res = trainer.test(model=trainmodule, test_dataloaders=test_loader)
# Out:
# ---------data----------
# num_attributes : 4
# num_attr_vals : 3
# num_cards_per_query : 2
# nest_depth_int : 2
# key_support_size : 81
# query_support_size : 6561
# hold_out : False
# train_datapoints length : 6561
# val_datapoints length : 6561
# train_tokens length : 6561
# val_tokens length : 6561
# sparsity_estimate : 0.012345679012345678
# vocab_size : 19
# ( : 12
# ) : 13
# NULL : 14
# SEP : 15
# SOS : 16
# EOS : 17
# PAD : 18
# -----------------------
# Testing: 0it [00:00, ?it/s]query
#  0
#  [12, 0, 3, 6, 9, 0, 3, 6, 9, 13]
# key
#  0
#  [0, 3, 6, 9]
# query
#  1
#  [12, 0, 3, 6, 9, 0, 3, 6, 10, 13]
# key
#  2
#  [0, 3, 6, 11]
# query
#  2
#  [12, 0, 3, 6, 9, 0, 3, 6, 11, 13]
# key
#  1
#  [0, 3, 6, 10]
# query
#  3
#  [12, 0, 3, 6, 9, 0, 3, 7, 9, 13]
# key
#  6
#  [0, 3, 8, 9]
# query
#  4
#  [12, 0, 3, 6, 9, 0, 3, 7, 10, 13]
# key
#  8
#  [0, 3, 8, 11]
# query
#  5
#  [12, 0, 3, 6, 9, 0, 3, 7, 11, 13]
# key
#  7
#  [0, 3, 8, 10]
# query
#  6
#  [12, 0, 3, 6, 9, 0, 3, 8, 9, 13]
# key
#  3
#  [0, 3, 7, 9]
# query
#  7
#  [12, 0, 3, 6, 9, 0, 3, 8, 10, 13]
# key
#  5
#  [0, 3, 7, 11]
# query
#  8
#  [12, 0, 3, 6, 9, 0, 3, 8, 11, 13]
# key
#  4
#  [0, 3, 7, 10]
# query
#  9
#  [12, 0, 3, 6, 9, 0, 4, 6, 9, 13]
# key
#  18
#  [0, 5, 6, 9]
# query
#  10
#  [12, 0, 3, 6, 9, 0, 4, 6, 10, 13]
# key
#  20
#  [0, 5, 6, 11]
# query
#  11
#  [12, 0, 3, 6, 9, 0, 4, 6, 11, 13]
# key
#  19
#  [0, 5, 6, 10]
# query
#  12
#  [12, 0, 3, 6, 9, 0, 4, 7, 9, 13]
# key
#  24
#  [0, 5, 8, 9]
# query
#  13
#  [12, 0, 3, 6, 9, 0, 4, 7, 10, 13]
# key
#  26
#  [0, 5, 8, 11]
# query
#  14
#  [12, 0, 3, 6, 9, 0, 4, 7, 11, 13]
# key
#  25
#  [0, 5, 8, 10]
# query
#  15
#  [12, 0, 3, 6, 9, 0, 4, 8, 9, 13]
# key
#  21
#  [0, 5, 7, 9]
# query
#  16
#  [12, 0, 3, 6, 9, 0, 4, 8, 10, 13]
# key
#  23
#  [0, 5, 7, 11]
# query
#  17
#  [12, 0, 3, 6, 9, 0, 4, 8, 11, 13]
# key
#  22
#  [0, 5, 7, 10]
# query
#  18
#  [12, 0, 3, 6, 9, 0, 5, 6, 9, 13]
# key
#  9
#  [0, 4, 6, 9]
# query
#  19
#  [12, 0, 3, 6, 9, 0, 5, 6, 10, 13]
# key
#  11
#  [0, 4, 6, 11]
# query
#  20
#  [12, 0, 3, 6, 9, 0, 5, 6, 11, 13]
# key
#  10
#  [0, 4, 6, 10]
# query
#  21
#  [12, 0, 3, 6, 9, 0, 5, 7, 9, 13]
# key
#  15
#  [0, 4, 8, 9]
# query
#  22
#  [12, 0, 3, 6, 9, 0, 5, 7, 10, 13]
# key
#  17
#  [0, 4, 8, 11]
# query
#  23
#  [12, 0, 3, 6, 9, 0, 5, 7, 11, 13]
# key
#  16
#  [0, 4, 8, 10]
# query
#  24
#  [12, 0, 3, 6, 9, 0, 5, 8, 9, 13]
# key
#  12
#  [0, 4, 7, 9]
# query
#  25
#  [12, 0, 3, 6, 9, 0, 5, 8, 10, 13]
# key
#  14
#  [0, 4, 7, 11]
# query
#  26
#  [12, 0, 3, 6, 9, 0, 5, 8, 11, 13]
# key
#  13
#  [0, 4, 7, 10]
# query
#  27
#  [12, 0, 3, 6, 9, 1, 3, 6, 9, 13]
# key
#  54
#  [2, 3, 6, 9]
# query
#  28
#  [12, 0, 3, 6, 9, 1, 3, 6, 10, 13]
# key
#  56
#  [2, 3, 6, 11]
# query
#  29
#  [12, 0, 3, 6, 9, 1, 3, 6, 11, 13]
# key
#  55
#  [2, 3, 6, 10]
# query
#  30
#  [12, 0, 3, 6, 9, 1, 3, 7, 9, 13]
# key
#  60
#  [2, 3, 8, 9]
# query
#  31
#  [12, 0, 3, 6, 9, 1, 3, 7, 10, 13]
# key
#  62
#  [2, 3, 8, 11]
# Testing:   0%|          | 32/6561 [00:00<00:20, 317.83it/s]
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, test dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# /app/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/dataraw_sampling.py:94: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if part == '(':
# /app/Contrastive-Learning-Benchmarking/SecondPass-CardGame-experiments/dataraw_sampling.py:96: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif part == ')':
# query
#  32
#  [12, 0, 3, 6, 9, 1, 3, 7, 11, 13]
# key
#  61
#  [2, 3, 8, 10]
# query
#  33
#  [12, 0, 3, 6, 9, 1, 3, 8, 9, 13]
# key
#  57
#  [2, 3, 7, 9]
# query
#  34
#  [12, 0, 3, 6, 9, 1, 3, 8, 10, 13]
# key
#  59
#  [2, 3, 7, 11]
# query
#  35
#  [12, 0, 3, 6, 9, 1, 3, 8, 11, 13]
# key
#  58
#  [2, 3, 7, 10]
# query
#  36
#  [12, 0, 3, 6, 9, 1, 4, 6, 9, 13]
# key
#  72
#  [2, 5, 6, 9]
# query
#  37
#  [12, 0, 3, 6, 9, 1, 4, 6, 10, 13]
# key
#  74
#  [2, 5, 6, 11]
# query
#  38
#  [12, 0, 3, 6, 9, 1, 4, 6, 11, 13]
# key
#  73
#  [2, 5, 6, 10]
# query
#  39
#  [12, 0, 3, 6, 9, 1, 4, 7, 9, 13]
# key
#  78
#  [2, 5, 8, 9]
# query
#  40
#  [12, 0, 3, 6, 9, 1, 4, 7, 10, 13]
# key
#  80
#  [2, 5, 8, 11]
# query
#  41
#  [12, 0, 3, 6, 9, 1, 4, 7, 11, 13]
# key
#  79
#  [2, 5, 8, 10]
# query
#  42
#  [12, 0, 3, 6, 9, 1, 4, 8, 9, 13]
# key
#  75
#  [2, 5, 7, 9]
# query
#  43
#  [12, 0, 3, 6, 9, 1, 4, 8, 10, 13]
# key
#  77
#  [2, 5, 7, 11]
# query
#  44
#  [12, 0, 3, 6, 9, 1, 4, 8, 11, 13]
# key
#  76
#  [2, 5, 7, 10]
# query
#  45
#  [12, 0, 3, 6, 9, 1, 5, 6, 9, 13]
# key
#  63
#  [2, 4, 6, 9]
# query
#  46
#  [12, 0, 3, 6, 9, 1, 5, 6, 10, 13]
# key
#  65
#  [2, 4, 6, 11]
# query
#  47
#  [12, 0, 3, 6, 9, 1, 5, 6, 11, 13]
# key
#  64
#  [2, 4, 6, 10]
# query
#  48
#  [12, 0, 3, 6, 9, 1, 5, 7, 9, 13]
# key
#  69
#  [2, 4, 8, 9]
# query
#  49
#  [12, 0, 3, 6, 9, 1, 5, 7, 10, 13]
# key
#  71
#  [2, 4, 8, 11]
# query
#  50
#  [12, 0, 3, 6, 9, 1, 5, 7, 11, 13]
# key
#  70
#  [2, 4, 8, 10]
# query
#  51
#  [12, 0, 3, 6, 9, 1, 5, 8, 9, 13]
# key
#  66
#  [2, 4, 7, 9]
# query
#  52
#  [12, 0, 3, 6, 9, 1, 5, 8, 10, 13]
# key
#  68
#  [2, 4, 7, 11]
# query
#  53
#  [12, 0, 3, 6, 9, 1, 5, 8, 11, 13]
# key
#  67
#  [2, 4, 7, 10]
# query
#  54
#  [12, 0, 3, 6, 9, 2, 3, 6, 9, 13]
# key
#  27
#  [1, 3, 6, 9]
# query
#  55
#  [12, 0, 3, 6, 9, 2, 3, 6, 10, 13]
# key
#  29
#  [1, 3, 6, 11]
# query
#  56
#  [12, 0, 3, 6, 9, 2, 3, 6, 11, 13]
# key
#  28
#  [1, 3, 6, 10]
# query
#  57
#  [12, 0, 3, 6, 9, 2, 3, 7, 9, 13]
# key
#  33
#  [1, 3, 8, 9]
# query
#  58
#  [12, 0, 3, 6, 9, 2, 3, 7, 10, 13]
# key
#  35
#  [1, 3, 8, 11]
# query
#  59
#  [12, 0, 3, 6, 9, 2, 3, 7, 11, 13]
# key
#  34
#  [1, 3, 8, 10]
# query
#  60
#  [12, 0, 3, 6, 9, 2, 3, 8, 9, 13]
# key
#  30
#  [1, 3, 7, 9]
# query
#  61
#  [12, 0, 3, 6, 9, 2, 3, 8, 10, 13]
# key
#  32
#  [1, 3, 7, 11]
# query
#  62
#  [12, 0, 3, 6, 9, 2, 3, 8, 11, 13]
# key
#  31
#  [1, 3, 7, 10]
# query
#  63
#  [12, 0, 3, 6, 9, 2, 4, 6, 9, 13]
# key
#  45
#  [1, 5, 6, 9]
# query
#  64
#  [12, 0, 3, 6, 9, 2, 4, 6, 10, 13]
# key
#  47
#  [1, 5, 6, 11]
# query
#  65
#  [12, 0, 3, 6, 9, 2, 4, 6, 11, 13]
# key
#  46
#  [1, 5, 6, 10]
# Testing:   1%|          | 66/6561 [00:00<00:20, 323.36it/s]query
#  66
#  [12, 0, 3, 6, 9, 2, 4, 7, 9, 13]
# key
#  51
#  [1, 5, 8, 9]
# query
#
 13]
# key
#  69
#  [2, 4, 8, 9]
# query
#  6462
#  [12, 2, 5, 8, 10, 2, 4, 6, 9, 13]
# key
#  59
#  [2, 3, 7, 11]
# query
#  6463
#  [12, 2, 5, 8, 10, 2, 4, 6, 10, 13]
# key
#  58
#  [2, 3, 7, 10]
# query
#  6464
#  [12, 2, 5, 8, 10, 2, 4, 6, 11, 13]
# key
#  57
#  [2, 3, 7, 9]
# query
#  6465
#  [12, 2, 5, 8, 10, 2, 4, 7, 9, 13]
# key
#  56
#  [2, 3, 6, 11]
# query
#  6466
#  [12, 2, 5, 8, 10, 2, 4, 7, 10, 13]
# key
#  55
#  [2, 3, 6, 10]
# query
#  6467
#  [12, 2, 5, 8, 10, 2, 4, 7, 11, 13]
# key
#  54
#  [2, 3, 6, 9]
# query
#  6468
#  [12, 2, 5, 8, 10, 2, 4, 8, 9, 13]
# key
#  62
#  [2, 3, 8, 11]
# query
#  6469
#  [12, 2, 5, 8, 10, 2, 4, 8, 10, 13]
# key
#  61
#  [2, 3, 8, 10]
# Testing:  99%|█████████▊| 6470/6561 [00:25<00:00, 248.34it/s]query
#  6470
#  [12, 2, 5, 8, 10, 2, 4, 8, 11, 13]
# key
#  60
#  [2, 3, 8, 9]
# query
#  6471
#  [12, 2, 5, 8, 10, 2, 5, 6, 9, 13]
# key
#  77
#  [2, 5, 7, 11]
# query
#  6472
#  [12, 2, 5, 8, 10, 2, 5, 6, 10, 13]
# key
#  76
#  [2, 5, 7, 10]
# query
#  6473
#  [12, 2, 5, 8, 10, 2, 5, 6, 11, 13]
# key
#  75
#  [2, 5, 7, 9]
# query
#  6474
#  [12, 2, 5, 8, 10, 2, 5, 7, 9, 13]
# key
#  74
#  [2, 5, 6, 11]
# query
#  6475
#  [12, 2, 5, 8, 10, 2, 5, 7, 10, 13]
# key
#  73
#  [2, 5, 6, 10]
# query
#  6476
#  [12, 2, 5, 8, 10, 2, 5, 7, 11, 13]
# key
#  72
#  [2, 5, 6, 9]
# query
#  6477
#  [12, 2, 5, 8, 10, 2, 5, 8, 9, 13]
# key
#  80
#  [2, 5, 8, 11]
# query
#  6478
#  [12, 2, 5, 8, 10, 2, 5, 8, 10, 13]
# key
#  79
#  [2, 5, 8, 10]
# query
#  6479
#  [12, 2, 5, 8, 10, 2, 5, 8, 11, 13]
# key
#  78
#  [2, 5, 8, 9]
# query
#  6480
#  [12, 2, 5, 8, 11, 0, 3, 6, 9, 13]
# key
#  40
#  [1, 4, 7, 10]
# query
#  6481
#  [12, 2, 5, 8, 11, 0, 3, 6, 10, 13]
# key
#  39
#  [1, 4, 7, 9]
# query
#  6482
#  [12, 2, 5, 8, 11, 0, 3, 6, 11, 13]
# key
#  41
#  [1, 4, 7, 11]
# query
#  6483
#  [12, 2, 5, 8, 11, 0, 3, 7, 9, 13]
# key
#  37
#  [1, 4, 6, 10]
# query
#  6484
#  [12, 2, 5, 8, 11, 0, 3, 7, 10, 13]
# key
#  36
#  [1, 4, 6, 9]
# query
#  6485
#  [12, 2, 5, 8, 11, 0, 3, 7, 11, 13]
# key
#  38
#  [1, 4, 6, 11]
# query
#  6486
#  [12, 2, 5, 8, 11, 0, 3, 8, 9, 13]
# key
#  43
#  [1, 4, 8, 10]
# query
#  6487
#  [12, 2, 5, 8, 11, 0, 3, 8, 10, 13]
# key
#  42
#  [1, 4, 8, 9]
# query
#  6488
#  [12, 2, 5, 8, 11, 0, 3, 8, 11, 13]
# key
#  44
#  [1, 4, 8, 11]
# query
#  6489
#  [12, 2, 5, 8, 11, 0, 4, 6, 9, 13]
# key
#  31
#  [1, 3, 7, 10]
# query
#  6490
#  [12, 2, 5, 8, 11, 0, 4, 6, 10, 13]
# key
#  30
#  [1, 3, 7, 9]
# query
#  6491
#  [12, 2, 5, 8, 11, 0, 4, 6, 11, 13]
# key
#  32
#  [1, 3, 7, 11]
# query
#  6492
#  [12, 2, 5, 8, 11, 0, 4, 7, 9, 13]
# key
#  28
#  [1, 3, 6, 10]
# query
#  6493
#  [12, 2, 5, 8, 11, 0, 4, 7, 10, 13]
# key
#  27
#  [1, 3, 6, 9]
# query
#  6494
#  [12, 2, 5, 8, 11, 0, 4, 7, 11, 13]
# key
#  29
#  [1, 3, 6, 11]
# Testing:  99%|█████████▉| 6495/6561 [00:25<00:00, 242.89it/s]query
#  6495
#  [12, 2, 5, 8, 11, 0, 4, 8, 9, 13]
# key
#  34
#  [1, 3, 8, 10]
# query
#  6496
#  [12, 2, 5, 8, 11, 0, 4, 8, 10, 13]
# key
#  33
#  [1, 3, 8, 9]
# query
#  6497
#  [12, 2, 5, 8, 11, 0, 4, 8, 11, 13]
# key
#  35
#  [1, 3, 8, 11]
# query
#  6498
#  [12, 2, 5, 8, 11, 0, 5, 6, 9, 13]
# key
#  49
#  [1, 5, 7, 10]
# query
#  6499
#  [12, 2, 5, 8, 11, 0, 5, 6, 10, 13]
# key
#  48
#  [1, 5, 7, 9]
# query
#  6500
#  [12, 2, 5, 8, 11, 0, 5, 6, 11, 13]
# key
#  50
#  [1, 5, 7, 11]
# query
#  6501
#  [12, 2, 5, 8, 11, 0, 5, 7, 9, 13]
# key
#  46
#  [1, 5, 6, 10]
# query
#  6502
#  [12, 2, 5, 8, 11, 0, 5, 7, 10, 13]
# key
#  45
#  [1, 5, 6, 9]
# query
#  6503
#  [12, 2, 5, 8, 11, 0, 5, 7, 11, 13]
# key
#  47
#  [1, 5, 6, 11]
# query
#  6504
#  [12, 2, 5, 8, 11, 0, 5, 8, 9, 13]
# key
#  52
#  [1, 5, 8, 10]
# query
#  6505
#  [12, 2, 5, 8, 11, 0, 5, 8, 10, 13]
# key
#  51
#  [1, 5, 8, 9]
# query
#  6506
#  [12, 2, 5, 8, 11, 0, 5, 8, 11, 13]
# key
#  53
#  [1, 5, 8, 11]
# query
#  6507
#  [12, 2, 5, 8, 11, 1, 3, 6, 9, 13]
# key
#  13
#  [0, 4, 7, 10]
# query
#  6508
#  [12, 2, 5, 8, 11, 1, 3, 6, 10, 13]
# key
#  12
#  [0, 4, 7, 9]
# query
#  6509
#  [12, 2, 5, 8, 11, 1, 3, 6, 11, 13]
# key
#  14
#  [0, 4, 7, 11]
# query
#  6510
#  [12, 2, 5, 8, 11, 1, 3, 7, 9, 13]
# key
#  10
#  [0, 4, 6, 10]
# query
#  6511
#  [12, 2, 5, 8, 11, 1, 3, 7, 10, 13]
# key
#  9
#  [0, 4, 6, 9]
# query
#  6512
#  [12, 2, 5, 8, 11, 1, 3, 7, 11, 13]
# key
#  11
#  [0, 4, 6, 11]
# query
#  6513
#  [12, 2, 5, 8, 11, 1, 3, 8, 9, 13]
# key
#  16
#  [0, 4, 8, 10]
# query
#  6514
#  [12, 2, 5, 8, 11, 1, 3, 8, 10, 13]
# key
#  15
#  [0, 4, 8, 9]
# query
#  6515
#  [12, 2, 5, 8, 11, 1, 3, 8, 11, 13]
# key
#  17
#  [0, 4, 8, 11]
# query
#  6516
#  [12, 2, 5, 8, 11, 1, 4, 6, 9, 13]
# key
#  4
#  [0, 3, 7, 10]
# query
#  6517
#  [12, 2, 5, 8, 11, 1, 4, 6, 10, 13]
# key
#  3
#  [0, 3, 7, 9]
# query
#  6518
#  [12, 2, 5, 8, 11, 1, 4, 6, 11, 13]
# key
#  5
#  [0, 3, 7, 11]
# query
#  6519
#  [12, 2, 5, 8, 11, 1, 4, 7, 9, 13]
# key
#  1
#  [0, 3, 6, 10]
# Testing:  99%|█████████▉| 6520/6561 [00:25<00:00, 240.18it/s]query
#  6520
#  [12, 2, 5, 8, 11, 1, 4, 7, 10, 13]
# key
#  0
#  [0, 3, 6, 9]
# query
#  6521
#  [12, 2, 5, 8, 11, 1, 4, 7, 11, 13]
# key
#  2
#  [0, 3, 6, 11]
# query
#  6522
#  [12, 2, 5, 8, 11, 1, 4, 8, 9, 13]
# key
#  7
#  [0, 3, 8, 10]
# query
#  6523
#  [12, 2, 5, 8, 11, 1, 4, 8, 10, 13]
# key
#  6
#  [0, 3, 8, 9]
# query
#  6524
#  [12, 2, 5, 8, 11, 1, 4, 8, 11, 13]
# key
#  8
#  [0, 3, 8, 11]
# query
#  6525
#  [12, 2, 5, 8, 11, 1, 5, 6, 9, 13]
# key
#  22
#  [0, 5, 7, 10]
# query
#  6526
#  [12, 2, 5, 8, 11, 1, 5, 6, 10, 13]
# key
#  21
#  [0, 5, 7, 9]
# query
#  6527
#  [12, 2, 5, 8, 11, 1, 5, 6, 11, 13]
# key
#  23
#  [0, 5, 7, 11]
# query
#  6528
#  [12, 2, 5, 8, 11, 1, 5, 7, 9, 13]
# key
#  19
#  [0, 5, 6, 10]
# query
#  6529
#  [12, 2, 5, 8, 11, 1, 5, 7, 10, 13]
# key
#  18
#  [0, 5, 6, 9]
# query
#  6530
#  [12, 2, 5, 8, 11, 1, 5, 7, 11, 13]
# key
#  20
#  [0, 5, 6, 11]
# query
#  6531
#  [12, 2, 5, 8, 11, 1, 5, 8, 9, 13]
# key
#  25
#  [0, 5, 8, 10]
# query
#  6532
#  [12, 2, 5, 8, 11, 1, 5, 8, 10, 13]
# key
#  24
#  [0, 5, 8, 9]
# query
#  6533
#  [12, 2, 5, 8, 11, 1, 5, 8, 11, 13]
# key
#  26
#  [0, 5, 8, 11]
# query
#  6534
#  [12, 2, 5, 8, 11, 2, 3, 6, 9, 13]
# key
#  67
#  [2, 4, 7, 10]
# query
#  6535
#  [12, 2, 5, 8, 11, 2, 3, 6, 10, 13]
# key
#  66
#  [2, 4, 7, 9]
# query
#  6536
#  [12, 2, 5, 8, 11, 2, 3, 6, 11, 13]
# key
#  68
#  [2, 4, 7, 11]
# query
#  6537
#  [12, 2, 5, 8, 11, 2, 3, 7, 9, 13]
# key
#  64
#  [2, 4, 6, 10]
# query
#  6538
#  [12, 2, 5, 8, 11, 2, 3, 7, 10, 13]
# key
#  63
#  [2, 4, 6, 9]
# query
#  6539
#  [12, 2, 5, 8, 11, 2, 3, 7, 11, 13]
# key
#  65
#  [2, 4, 6, 11]
# query
#  6540
#  [12, 2, 5, 8, 11, 2, 3, 8, 9, 13]
# key
#  70
#  [2, 4, 8, 10]
# query
#  6541
#  [12, 2, 5, 8, 11, 2, 3, 8, 10, 13]
# key
#  69
#  [2, 4, 8, 9]
# query
#  6542
#  [12, 2, 5, 8, 11, 2, 3, 8, 11, 13]
# key
#  71
#  [2, 4, 8, 11]
# query
#  6543
#  [12, 2, 5, 8, 11, 2, 4, 6, 9, 13]
# key
#  58
#  [2, 3, 7, 10]
# query
#  6544
#  [12, 2, 5, 8, 11, 2, 4, 6, 10, 13]
# key
#  57
#  [2, 3, 7, 9]
# Testing: 100%|█████████▉| 6545/6561 [00:25<00:00, 242.22it/s]query
#  6545
#  [12, 2, 5, 8, 11, 2, 4, 6, 11, 13]
# key
#  59
#  [2, 3, 7, 11]
# query
#  6546
#  [12, 2, 5, 8, 11, 2, 4, 7, 9, 13]
# key
#  55
#  [2, 3, 6, 10]
# query
#  6547
#  [12, 2, 5, 8, 11, 2, 4, 7, 10, 13]
# key
#  54
#  [2, 3, 6, 9]
# query
#  6548
#  [12, 2, 5, 8, 11, 2, 4, 7, 11, 13]
# key
#  56
#  [2, 3, 6, 11]
# query
#  6549
#  [12, 2, 5, 8, 11, 2, 4, 8, 9, 13]
# key
#  61
#  [2, 3, 8, 10]
# query
#  6550
#  [12, 2, 5, 8, 11, 2, 4, 8, 10, 13]
# key
#  60
#  [2, 3, 8, 9]
# query
#  6551
#  [12, 2, 5, 8, 11, 2, 4, 8, 11, 13]
# key
#  62
#  [2, 3, 8, 11]
# query
#  6552
#  [12, 2, 5, 8, 11, 2, 5, 6, 9, 13]
# key
#  76
#  [2, 5, 7, 10]
# query
#  6553
#  [12, 2, 5, 8, 11, 2, 5, 6, 10, 13]
# key
#  75
#  [2, 5, 7, 9]
# query
#  6554
#  [12, 2, 5, 8, 11, 2, 5, 6, 11, 13]
# key
#  77
#  [2, 5, 7, 11]
# query
#  6555
#  [12, 2, 5, 8, 11, 2, 5, 7, 9, 13]
# key
#  73
#  [2, 5, 6, 10]
# query
#  6556
#  [12, 2, 5, 8, 11, 2, 5, 7, 10, 13]
# key
#  72
#  [2, 5, 6, 9]
# query
#  6557
#  [12, 2, 5, 8, 11, 2, 5, 7, 11, 13]
# key
#  74
#  [2, 5, 6, 11]
# query
#  6558
#  [12, 2, 5, 8, 11, 2, 5, 8, 9, 13]
# key
#  79
#  [2, 5, 8, 10]
# query
#  6559
#  [12, 2, 5, 8, 11, 2, 5, 8, 10, 13]
# key
#  78
#  [2, 5, 8, 9]
# query
#  6560
#  [12, 2, 5, 8, 11, 2, 5, 8, 11, 13]
# key
#  80
#  [2, 5, 8, 11]
# Testing: 100%|██████████| 6561/6561 [00:25<00:00, 253.05it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'avg_test_accuracy': 0.9999999403953552, 'test_accuracy': 1.0}
# --------------------------------------------------------------------------------
# /home/user/miniconda/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The testing_epoch_end should not return anything as of 9.1. To log, use self.log(...) or self.write(...) directly in the LightningModule
#   warnings.warn(*args, **kwargs)

# %%
# Original with SGD 
# 1 epoch

Profiler Report

Action                             	|  Mean duration (s)	|Num calls	|  Total time (s)|  Percentage %   	|
--------------------------------------------------------------------------------------------------------------------------
Total                              	|  -              	|_            |  111.9          |  100 %          	|
--------------------------------------------------------------------------------------------------------------------------
run_training_epoch                 	|  106.02         	|1            |  106.02         |  94.748         	|
run_training_batch                 	|  0.84838        	|94           |  79.748         |  71.267         	|
optimizer_step_and_closure_0       	|  0.848          	|94           |  79.712         |  71.235         	|
training_step_and_backward         	|  0.84785        	|94           |  79.698         |  71.222         	|
model_forward                      	|  0.84431        	|94           |  79.365         |  70.924         	|
training_step                      	|  0.844          	|94           |  79.336         |  70.899         	|
get_train_batch                    	|  0.2482         	|94           |  23.331         |  20.849         	|
evaluation_step_and_end            	|  1.014          	|4            |  4.0559         |  3.6246         	|
validation_step                    	|  1.0138         	|4            |  4.0551         |  3.6238         	|
model_backward                     	|  0.0028811      	|94           |  0.27082        |  0.24202        	|
on_train_batch_end                 	|  0.0019145      	|94           |  0.17996        |  0.16082        	|
on_validation_end                  	|  0.050853       	|2            |  0.10171        |  0.090889       	|
cache_result                       	|  1.9878e-05     	|501          |  0.0099588      |  0.0088996      	|
on_validation_batch_end            	|  0.0019233      	|4            |  0.0076931      |  0.0068749      	|
on_train_end                       	|  0.0066462      	|1            |  0.0066462      |  0.0059394      	|
on_validation_start                	|  0.0020034      	|2            |  0.0040068      |  0.0035807      	|
on_batch_start                     	|  2.7216e-05     	|94           |  0.0025583      |  0.0022862      	|
on_after_backward                  	|  1.6831e-05     	|94           |  0.0015821      |  0.0014139      	|
on_epoch_start                     	|  0.0015688      	|1            |  0.0015688      |  0.001402       	|
on_train_start                     	|  0.0012749      	|1            |  0.0012749      |  0.0011393      	|
on_batch_end                       	|  1.354e-05      	|94           |  0.0012727      |  0.0011374      	|
training_step_end                  	|  1.2981e-05     	|94           |  0.0012202      |  0.0010905      	|
on_before_zero_grad                	|  1.2896e-05     	|94           |  0.0012122      |  0.0010833      	|
on_train_batch_start               	|  1.0139e-05     	|94           |  0.0009531      |  0.00085173     	|
on_validation_batch_start          	|  1.9116e-05     	|4            |  7.6465e-05     |  6.8333e-05     	|
on_fit_start                       	|  4.8612e-05     	|1            |  4.8612e-05     |  4.3442e-05     	|
validation_step_end                	|  1.1254e-05     	|4            |  4.5015e-05     |  4.0227e-05     	|
on_epoch_end                       	|  1.0189e-05     	|3            |  3.0568e-05     |  2.7317e-05     	|
on_validation_epoch_end            	|  1.5259e-05     	|2            |  3.0518e-05     |  2.7272e-05     	|
on_train_epoch_end                 	|  2.0348e-05     	|1            |  2.0348e-05     |  1.8184e-05     	|
on_validation_epoch_start          	|  9.6985e-06     	|2            |  1.9397e-05     |  1.7334e-05     	|
on_train_epoch_start               	|  1.6231e-05     	|1            |  1.6231e-05     |  1.4505e-05     	|
on_before_accelerator_backend_setup	|  8.957e-06      	|1            |  8.957e-06      |  8.0044e-06     	|

# %%
# Do not compute metrics during training
# 1 epoch

Profiler Report

Action                             	|  Mean duration (s)	|Num calls |  Total time (s) 	|  Percentage %   	|
-------------------------------------------------------------------------------------------------------------------------------
Total                              	|  -              	|_             |  31.589         	|  100 %          	|
-------------------------------------------------------------------------------------------------------------------------------
run_training_epoch                 	|  27.208         	|1             |  27.208         	|  86.132         	|
get_train_batch                    	|  0.24756        	|94            |  23.27          	|  73.666         	|
evaluation_step_and_end            	|  0.91329        	|4             |  3.6532         	|  11.565         	|
validation_step                    	|  0.91311        	|4             |  3.6524         	|  11.562         	|
run_training_batch                 	|  0.014024       	|94            |  1.3183         	|  4.1732         	|
optimizer_step_and_closure_0       	|  0.013643       	|94            |  1.2824         	|  4.0598         	|
training_step_and_backward         	|  0.013501       	|94            |  1.2691         	|  4.0176         	|
model_forward                      	|  0.010339       	|94            |  0.9719         	|  3.0767         	|
training_step                      	|  0.010142       	|94            |  0.95336        	|  3.0181         	|
model_backward                     	|  0.0027228      	|94            |  0.25595        	|  0.81025        	|
on_train_batch_end                 	|  0.0019353      	|94            |  0.18192        	|  0.57591        	|
on_validation_end                  	|  0.043622       	|2             |  0.087243       	|  0.27619        	|
on_train_end                       	|  0.0083497      	|1             |  0.0083497      	|  0.026433       	|
cache_result                       	|  1.4289e-05     	|501           |  0.0071588      	|  0.022663       	|
on_validation_batch_end            	|  0.0016247      	|4             |  0.006499       	|  0.020574       	|
on_validation_start                	|  0.002297       	|2             |  0.004594       	|  0.014543       	|
on_batch_start                     	|  3.0167e-05     	|94            |  0.0028357      	|  0.008977       	|
on_epoch_start                     	|  0.001795       	|1             |  0.001795       	|  0.0056824      	|
on_after_backward                  	|  1.4745e-05     	|94            |  0.001386       	|  0.0043878      	|
on_train_start                     	|  0.0013637      	|1             |  0.0013637      	|  0.0043171      	|
on_before_zero_grad                	|  1.2626e-05     	|94            |  0.0011868      	|  0.0037571      	|
on_batch_end                       	|  1.2578e-05     	|94            |  0.0011824      	|  0.003743       	|
on_train_batch_start               	|  1.1199e-05     	|94            |  0.0010527      	|  0.0033325      	|
training_step_end                  	|  9.135e-06      	|94            |  0.00085869     	|  0.0027184      	|
on_validation_batch_start          	|  1.7729e-05     	|4             |  7.0915e-05     	|  0.00022449     	|
validation_step_end                	|  1.291e-05      	|4             |  5.1639e-05     	|  0.00016347     	|
on_fit_start                       	|  3.9244e-05     	|1             |  3.9244e-05     	|  0.00012423     	|
on_validation_epoch_start          	|  1.5339e-05     	|2             |  3.0679e-05     	|  9.712e-05      	|
on_epoch_end                       	|  9.869e-06      	|3             |  2.9607e-05     	|  9.3727e-05     	|
on_validation_epoch_end            	|  1.2123e-05     	|2             |  2.4246e-05     	|  7.6755e-05     	|
on_train_epoch_end                 	|  1.8796e-05     	|1             |  1.8796e-05     	|  5.9502e-05     	|
on_train_epoch_start               	|  1.8285e-05     	|1             |  1.8285e-05     	|  5.7885e-05     	|
on_before_accelerator_backend_setup	|  8.186e-06      	|1             |  8.186e-06      	|  2.5914e-05     	|

# %%
# With SET data
# 1 epoch

Profiler Report

Action                             	|  Mean duration (s)	|Num calls 	|  Total time (s) 	|  Percentage %   	|
-------------------------------------------------------------------------------------------------------------------------------
Total                              	|  -              	|_             |  2.7329         	|  100 %          	|
-------------------------------------------------------------------------------------------------------------------------------
run_training_epoch                 	|  0.54216        	|1             |  0.54216        	|  19.838         	|
evaluation_step_and_end            	|  0.026706       	|15            |  0.40059        	|  14.658         	|
validation_step                    	|  0.026586       	|15            |  0.39879        	|  14.592         	|
run_training_batch                 	|  0.013455       	|13            |  0.17491        	|  6.4004         	|
optimizer_step_and_closure_0       	|  0.013157       	|13            |  0.17104        	|  6.2586         	|
training_step_and_backward         	|  0.013081       	|13            |  0.17005        	|  6.2226         	|
on_validation_end                  	|  0.084182       	|2             |  0.16836        	|  6.1608         	|
model_forward                      	|  0.010066       	|13            |  0.13086        	|  4.7883         	|
training_step                      	|  0.0099253      	|13            |  0.12903        	|  4.7214         	|
get_train_batch                    	|  0.0035085      	|13            |  0.045611       	|  1.669          	|
model_backward                     	|  0.0025997      	|13            |  0.033796       	|  1.2366         	|
on_train_batch_end                 	|  0.0010495      	|13            |  0.013643       	|  0.49922        	|
on_train_end                       	|  0.010448       	|1             |  0.010448       	|  0.3823         	|
on_validation_start                	|  0.0016977      	|2             |  0.0033954      	|  0.12425        	|
on_validation_batch_end            	|  0.00013582     	|15            |  0.0020373      	|  0.07455        	|
cache_result                       	|  1.1597e-05     	|129           |  0.001496       	|  0.054741       	|
on_epoch_start                     	|  0.0011864      	|1             |  0.0011864      	|  0.043413       	|
on_train_start                     	|  0.0010186      	|1             |  0.0010186      	|  0.037273       	|
on_validation_batch_start          	|  1.1497e-05     	|15            |  0.00017245     	|  0.0063103      	|
on_after_backward                  	|  1.2964e-05     	|13            |  0.00016853     	|  0.0061669      	|
on_batch_start                     	|  1.2891e-05     	|13            |  0.00016758     	|  0.0061321      	|
on_batch_end                       	|  1.1612e-05     	|13            |  0.00015096     	|  0.0055238      	|
on_before_zero_grad                	|  1.161e-05      	|13            |  0.00015093     	|  0.0055227      	|
validation_step_end                	|  7.6145e-06     	|15            |  0.00011422     	|  0.0041794      	|
on_train_batch_start               	|  8.0615e-06     	|13            |  0.0001048      	|  0.0038348      	|
training_step_end                  	|  7.8904e-06     	|13            |  0.00010257     	|  0.0037534      	|
on_fit_start                       	|  4.0837e-05     	|1             |  4.0837e-05     	|  0.0014943      	|
on_validation_epoch_start          	|  1.7007e-05     	|2             |  3.4014e-05     	|  0.0012446      	|
on_epoch_end                       	|  9.01e-06       	|3             |  2.703e-05      	|  0.00098908     	|
on_validation_epoch_end            	|  1.2955e-05     	|2             |  2.5909e-05     	|  0.00094806     	|
on_train_epoch_end                 	|  1.0279e-05     	|1             |  1.0279e-05     	|  0.00037613     	|
on_train_epoch_start               	|  1.0049e-05     	|1             |  1.0049e-05     	|  0.00036771     	|
on_before_accelerator_backend_setup	|  7.294e-06      	|1             |  7.294e-06      	|  0.0002669      	|

# %%
# Simple Shatter
# Generative
# 1 epoch
# Adam LR Scheduled

Profiler Report

Action                             	|  Mean duration (s)	|Num calls      	|  Total time (s) 	|  Percentage %   	|
------------------------------------------------------------------------------------------------------------------------------------
Total                              	|  -              	|_              	|  21.072         	|  100 %          	|
------------------------------------------------------------------------------------------------------------------------------------
run_training_epoch                 	|  16.042         	|1              	|  16.042         	|  76.129         	|
run_training_batch                 	|  1.1156         	|11             	|  12.271         	|  58.234         	|
optimizer_step_and_closure_0       	|  1.1144         	|11             	|  12.259         	|  58.174         	|
training_step_and_backward         	|  1.1056         	|11             	|  12.162         	|  57.715         	|
model_backward                     	|  0.83573        	|11             	|  9.1931         	|  43.626         	|
evaluation_step_and_end            	|  0.33865        	|13             	|  4.4025         	|  20.892         	|
validation_step                    	|  0.33843        	|13             	|  4.3996         	|  20.879         	|
model_forward                      	|  0.26516        	|11             	|  2.9168         	|  13.842         	|
training_step                      	|  0.26488        	|11             	|  2.9137         	|  13.827         	|
get_train_batch                    	|  0.012527       	|11             	|  0.1378         	|  0.65393        	|
on_before_accelerator_backend_setup	|  0.071061       	|1              	|  0.071061       	|  0.33722        	|
on_validation_end                  	|  0.028403       	|2              	|  0.056806       	|  0.26958        	|
on_train_end                       	|  0.039158       	|1              	|  0.039158       	|  0.18583        	|
on_validation_batch_end            	|  0.0025681      	|13             	|  0.033385       	|  0.15843        	|
on_train_batch_end                 	|  0.0021         	|11             	|  0.0231         	|  0.10962        	|
on_validation_start                	|  0.0018488      	|2              	|  0.0036977      	|  0.017548       	|
cache_result                       	|  2.6432e-05     	|113            	|  0.0029869      	|  0.014174       	|
on_train_start                     	|  0.0026248      	|1              	|  0.0026248      	|  0.012456       	|
on_epoch_start                     	|  0.00111        	|1              	|  0.00111        	|  0.0052675      	|
on_after_backward                  	|  2.9594e-05     	|11             	|  0.00032553     	|  0.0015448      	|
on_batch_start                     	|  2.4907e-05     	|11             	|  0.00027398     	|  0.0013002      	|
on_validation_batch_start          	|  2.0466e-05     	|13             	|  0.00026605     	|  0.0012626      	|
on_before_zero_grad                	|  2.22e-05       	|11             	|  0.0002442      	|  0.0011589      	|
on_batch_end                       	|  1.7714e-05     	|11             	|  0.00019486     	|  0.00092472     	|
on_train_batch_start               	|  1.6916e-05     	|11             	|  0.00018607     	|  0.00088302     	|
validation_step_end                	|  1.2207e-05     	|13             	|  0.00015869     	|  0.00075307     	|
training_step_end                  	|  1.1702e-05     	|11             	|  0.00012873     	|  0.00061087     	|
on_validation_epoch_end            	|  2.5148e-05     	|2              	|  5.0295e-05     	|  0.00023868     	|
on_epoch_end                       	|  1.2677e-05     	|3              	|  3.8032e-05     	|  0.00018048     	|
on_fit_start                       	|  3.4335e-05     	|1              	|  3.4335e-05     	|  0.00016294     	|
on_validation_epoch_start          	|  1.3035e-05     	|2              	|  2.6069e-05     	|  0.00012371     	|
on_train_epoch_start               	|  2.0368e-05     	|1              	|  2.0368e-05     	|  9.6658e-05     	|
on_train_epoch_end                 	|  1.8705e-05     	|1              	|  1.8705e-05     	|  8.8766e-05     	|
